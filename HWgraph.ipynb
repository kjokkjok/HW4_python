# %%
from Bio import SeqIO
import Bio
from collections import defaultdict

class Vertex:
    
    def __init__(self, seq):
        self.seq = seq
        self.coverage = 1
        self.in_edges = {}
        self.out_edges = {}
        
    def increase_coverage(self):
        self.coverage += 1

class Edge:
    
    def __init__(self,k1,k2):
        self.seq = k1 + k2[-1]
        self.n = 2
        self.coverage = 0
    
    def calc_coverage(self,c1,c2):
        self.coverage = (c1+c2)/2


class Graph:

    def __init__(self,k):
        self.vertices = {}
        self.k = k
        
    def add_read(self,read):
        read_lng = len(read)
        if read_lng < self.k:
            return
            
        kmer = read[:k]
        if kmer in self.vertices:
            self.vertices[kmer].increase_coverage()
        else:
            self.vertices[kmer] = Vertex(kmer)
        
        for next_kmer_indx in range(1,read_lng-k+1,1):
            next_kmer = read[next_kmer_indx:(next_kmer_indx+k)]
            if next_kmer in self.vertices:
                self.vertices[next_kmer].increase_coverage()
            else:
                self.vertices[next_kmer] = Vertex(next_kmer)
            
            new_edge = Edge(kmer,next_kmer)
            
            self.vertices[next_kmer].in_edges[kmer]  = [new_edge]
            
            self.vertices[kmer].out_edges[next_kmer] = [new_edge]

            kmer = next_kmer
    
    def calc_init_edge_coverage(self):
        
        for current_vertex in self.vertices.keys():
            for next_vertex in self.vertices[current_vertex].out_edges.keys():
                self.vertices[current_vertex].out_edges[next_vertex][0].calc_coverage(self.vertices[current_vertex].coverage,self.vertices[next_vertex].coverage)
        
    def Graph_viz(self, PathToWrite, full):
        
        self.graph =  Digraph(comment='assembly')

        if full:
            for v, e in self.vertices.items():
                self.graph.node(v, label='{}'.format(v))
                
                for i, j in e.out_edges.items():
                    self.graph.edge(v, i,label='{}'.format(j[0].seq))

        else:
            for v, e in self.vertices.items():
                self.graph.node(v, label='coverage={}'.format(my_graph.vertices[v].coverage))
                
                for i, j in e.out_edges.items():
                    self.graph.edge(v, i,label='len={},cov={}'.format(len(j[0].seq), j[0].coverage))
        
        print(self.graph.source)
        with open (PathToWrite, 'w') as handle:
            handle.write(self.graph.source)
        
       

if __name__ == '__main__':
    
    dataset = 'Загрузки/hw_4_5_dataset.fasta'

    k = 5
    
    my_graph = Graph(k)
    direction = 'reverse'
    with open(dataset, "r") as handle:
        for record in SeqIO.parse(handle, "fasta"):
            if direction == 'reverse':
                read = str(record.reverse_complement().seq)
                my_graph.add_read(read)
            else:
                read = str(record.seq)
                my_graph.add_read(read)

    my_graph.calc_init_edge_coverage()
    
    
    for v in my_graph.vertices:
        print('Vertex: {}, coverage: {}'.format(v,my_graph.vertices[v].coverage))
        for e in my_graph.vertices[v].out_edges:
            print('-> Out edge: {}'.format(e))
        for e in my_graph.vertices[v].in_edges:
            print('-> In edge: {}'.format(e))            
    
    my_graph.Graph_viz('Graph.dot', full=False)
# Out:
# Vertex: GTGTA, coverage: 286
# -> Out edge: TGTAG
# -> Out edge: TGTAT
# -> Out edge: TGTAC
# -> Out edge: TGTAA
# -> In edge: GGTGT
# -> In edge: TGTGT
# -> In edge: AGTGT
# -> In edge: CGTGT
# Vertex: GCTCC, coverage: 457
# -> Out edge: CTCCA
# -> Out edge: CTCCC
# -> Out edge: CTCCG
# -> Out edge: CTCCT
# -> In edge: TGCTC
# -> In edge: GGCTC
# -> In edge: AGCTC
# -> In edge: CGCTC
# Vertex: AGTGC, coverage: 286
# -> Out edge: GTGCT
# -> Out edge: GTGCG
# -> Out edge: GTGCC
# -> Out edge: GTGCA
# -> In edge: TAGTG
# -> In edge: CAGTG
# -> In edge: GAGTG
# -> In edge: AAGTG
# Vertex: AACTC, coverage: 199
# -> Out edge: ACTCG
# -> Out edge: ACTCA
# -> Out edge: ACTCT
# -> Out edge: ACTCC
# -> In edge: AAACT
# -> In edge: TAACT
# -> In edge: CAACT
# -> In edge: GAACT
# Vertex: ATATC, coverage: 6
# -> Out edge: TATCT
# -> Out edge: TATCC
# -> In edge: AATAT
# -> In edge: CATAT
# -> In edge: TATAT
# -> In edge: GATAT
# Vertex: ACGCG, coverage: 101
# -> Out edge: CGCGA
# -> Out edge: CGCGG
# -> Out edge: CGCGT
# -> In edge: GACGC
# -> In edge: CACGC
# -> In edge: TACGC
# -> In edge: AACGC
# Vertex: GAGTT, coverage: 401
# -> Out edge: AGTTA
# -> Out edge: AGTTT
# -> Out edge: AGTTG
# -> Out edge: AGTTC
# -> In edge: AGAGT
# -> In edge: GGAGT
# -> In edge: TGAGT
# -> In edge: CGAGT
# Vertex: CTTTC, coverage: 111
# -> Out edge: TTTCG
# -> Out edge: TTTCT
# -> Out edge: TTTCA
# -> Out edge: TTTCC
# -> In edge: CCTTT
# -> In edge: TCTTT
# -> In edge: GCTTT
# -> In edge: ACTTT
# Vertex: TCCAC, coverage: 472
# -> Out edge: CCACG
# -> Out edge: CCACA
# -> Out edge: CCACT
# -> Out edge: CCACC
# -> In edge: CTCCA
# -> In edge: TTCCA
# -> In edge: GTCCA
# -> In edge: ATCCA
# Vertex: TAGCT, coverage: 187
# -> Out edge: AGCTT
# -> Out edge: AGCTC
# -> Out edge: AGCTA
# -> Out edge: AGCTG
# -> In edge: ATAGC
# -> In edge: GTAGC
# -> In edge: CTAGC
# -> In edge: TTAGC
# Vertex: ACTTA, coverage: 4
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> In edge: CACTT
# -> In edge: GACTT
# -> In edge: TACTT
# Vertex: CCTTG, coverage: 561
# -> Out edge: CTTGT
# -> Out edge: CTTGC
# -> Out edge: CTTGA
# -> Out edge: CTTGG
# -> In edge: GCCTT
# -> In edge: TCCTT
# -> In edge: CCCTT
# -> In edge: ACCTT
# Vertex: TCTTT, coverage: 562
# -> Out edge: CTTTT
# -> Out edge: CTTTA
# -> Out edge: CTTTC
# -> Out edge: CTTTG
# -> In edge: ATCTT
# -> In edge: TTCTT
# -> In edge: GTCTT
# -> In edge: CTCTT
# Vertex: CGCAT, coverage: 102
# -> Out edge: GCATA
# -> Out edge: GCATG
# -> Out edge: GCATT
# -> Out edge: GCATC
# -> In edge: CCGCA
# -> In edge: GCGCA
# -> In edge: ACGCA
# -> In edge: TCGCA
# Vertex: GACAG, coverage: 151
# -> Out edge: ACAGG
# -> Out edge: ACAGA
# -> Out edge: ACAGT
# -> Out edge: ACAGC
# -> In edge: CGACA
# -> In edge: AGACA
# -> In edge: GGACA
# -> In edge: TGACA
# Vertex: CTCCC, coverage: 290
# -> Out edge: TCCCT
# -> Out edge: TCCCC
# -> Out edge: TCCCG
# -> Out edge: TCCCA
# -> In edge: GCTCC
# -> In edge: CCTCC
# -> In edge: TCTCC
# -> In edge: ACTCC
# Vertex: GCTCG, coverage: 11
# -> Out edge: CTCGT
# -> Out edge: CTCGA
# -> Out edge: CTCGG
# -> In edge: TGCTC
# -> In edge: GGCTC
# -> In edge: AGCTC
# -> In edge: CGCTC
# Vertex: GCTGA, coverage: 379
# -> Out edge: CTGAA
# -> Out edge: CTGAC
# -> Out edge: CTGAG
# -> Out edge: CTGAT
# -> In edge: GGCTG
# -> In edge: AGCTG
# -> In edge: TGCTG
# -> In edge: CGCTG
# Vertex: TGCTA, coverage: 15
# -> Out edge: GCTAA
# -> Out edge: GCTAT
# -> Out edge: GCTAG
# -> Out edge: GCTAC
# -> In edge: GTGCT
# -> In edge: CTGCT
# -> In edge: ATGCT
# -> In edge: TTGCT
# Vertex: GAAGC, coverage: 117
# -> Out edge: AAGCA
# -> Out edge: AAGCG
# -> Out edge: AAGCC
# -> Out edge: AAGCT
# -> In edge: TGAAG
# -> In edge: AGAAG
# -> In edge: GGAAG
# -> In edge: CGAAG
# Vertex: AGTCC, coverage: 831
# -> Out edge: GTCCG
# -> Out edge: GTCCC
# -> Out edge: GTCCT
# -> Out edge: GTCCA
# -> In edge: TAGTC
# -> In edge: CAGTC
# -> In edge: GAGTC
# -> In edge: AAGTC
# Vertex: AACAA, coverage: 840
# -> Out edge: ACAAA
# -> Out edge: ACAAG
# -> Out edge: ACAAC
# -> Out edge: ACAAT
# -> In edge: TAACA
# -> In edge: AAACA
# -> In edge: CAACA
# -> In edge: GAACA
# Vertex: CATAT, coverage: 189
# -> Out edge: ATATT
# -> Out edge: ATATC
# -> Out edge: ATATA
# -> Out edge: ATATG
# -> In edge: GCATA
# -> In edge: CCATA
# -> In edge: TCATA
# -> In edge: ACATA
# Vertex: AAGGG, coverage: 666
# -> Out edge: AGGGA
# -> Out edge: AGGGG
# -> Out edge: AGGGT
# -> Out edge: AGGGC
# -> In edge: TAAGG
# -> In edge: AAAGG
# -> In edge: CAAGG
# -> In edge: GAAGG
# Vertex: TGGTA, coverage: 382
# -> Out edge: GGTAA
# -> Out edge: GGTAT
# -> Out edge: GGTAG
# -> Out edge: GGTAC
# -> In edge: TTGGT
# -> In edge: ATGGT
# -> In edge: GTGGT
# -> In edge: CTGGT
# Vertex: CATCT, coverage: 94
# -> Out edge: ATCTG
# -> Out edge: ATCTA
# -> Out edge: ATCTC
# -> In edge: GCATC
# -> In edge: CCATC
# Vertex: ACTGA, coverage: 473
# -> Out edge: CTGAC
# -> Out edge: CTGAG
# -> Out edge: CTGAT
# -> Out edge: CTGAA
# -> In edge: GACTG
# -> In edge: AACTG
# -> In edge: CACTG
# -> In edge: TACTG
# Vertex: CGTGT, coverage: 10
# -> Out edge: GTGTA
# -> Out edge: GTGTC
# -> Out edge: GTGTG
# -> Out edge: GTGTT
# -> In edge: TCGTG
# -> In edge: GCGTG
# -> In edge: CCGTG
# Vertex: GTCGG, coverage: 362
# -> Out edge: TCGGA
# -> Out edge: TCGGG
# -> Out edge: TCGGT
# -> Out edge: TCGGC
# -> In edge: CGTCG
# -> In edge: GGTCG
# -> In edge: AGTCG
# Vertex: ATTGG, coverage: 270
# -> Out edge: TTGGA
# -> Out edge: TTGGT
# -> Out edge: TTGGC
# -> Out edge: TTGGG
# -> In edge: AATTG
# -> In edge: GATTG
# -> In edge: TATTG
# -> In edge: CATTG
# Vertex: CACTT, coverage: 102
# -> Out edge: ACTTA
# -> Out edge: ACTTG
# -> Out edge: ACTTT
# -> Out edge: ACTTC
# -> In edge: ACACT
# -> In edge: TCACT
# -> In edge: CCACT
# -> In edge: GCACT
# Vertex: ACGTG, coverage: 104
# -> Out edge: CGTGA
# -> Out edge: CGTGC
# -> Out edge: CGTGG
# -> In edge: CACGT
# -> In edge: AACGT
# -> In edge: GACGT
# Vertex: GGTAA, coverage: 461
# -> Out edge: GTAAT
# -> Out edge: GTAAA
# -> Out edge: GTAAC
# -> Out edge: GTAAG
# -> In edge: AGGTA
# -> In edge: TGGTA
# -> In edge: CGGTA
# -> In edge: GGGTA
# Vertex: CCATG, coverage: 555
# -> Out edge: CATGA
# -> Out edge: CATGC
# -> Out edge: CATGT
# -> Out edge: CATGG
# -> In edge: CCCAT
# -> In edge: GCCAT
# -> In edge: TCCAT
# -> In edge: ACCAT
# Vertex: GTTTC, coverage: 224
# -> Out edge: TTTCG
# -> Out edge: TTTCT
# -> Out edge: TTTCA
# -> Out edge: TTTCC
# -> In edge: TGTTT
# -> In edge: CGTTT
# -> In edge: GGTTT
# -> In edge: AGTTT
# Vertex: CTATA, coverage: 198
# -> Out edge: TATAC
# -> Out edge: TATAT
# -> Out edge: TATAA
# -> Out edge: TATAG
# -> In edge: ACTAT
# -> In edge: TCTAT
# -> In edge: CCTAT
# Vertex: CGTGG, coverage: 101
# -> Out edge: GTGGC
# -> Out edge: GTGGG
# -> Out edge: GTGGT
# -> Out edge: GTGGA
# -> In edge: CCGTG
# -> In edge: TCGTG
# -> In edge: ACGTG
# Vertex: CGCTA, coverage: 100
# -> Out edge: GCTAA
# -> Out edge: GCTAT
# -> Out edge: GCTAG
# -> Out edge: GCTAC
# -> In edge: ACGCT
# -> In edge: CCGCT
# -> In edge: GCGCT
# Vertex: CGCTC, coverage: 6
# -> Out edge: GCTCT
# -> Out edge: GCTCG
# -> Out edge: GCTCC
# -> In edge: ACGCT
# -> In edge: GCGCT
# -> In edge: TCGCT
# -> In edge: CCGCT
# Vertex: TCCAG, coverage: 460
# -> Out edge: CCAGA
# -> Out edge: CCAGT
# -> Out edge: CCAGG
# -> Out edge: CCAGC
# -> In edge: CTCCA
# -> In edge: TTCCA
# -> In edge: GTCCA
# -> In edge: ATCCA
# Vertex: TAACA, coverage: 563
# -> Out edge: AACAG
# -> Out edge: AACAT
# -> Out edge: AACAA
# -> Out edge: AACAC
# -> In edge: TTAAC
# -> In edge: GTAAC
# -> In edge: CTAAC
# -> In edge: ATAAC
# Vertex: AGAAG, coverage: 1105
# -> Out edge: GAAGC
# -> Out edge: GAAGA
# -> Out edge: GAAGT
# -> Out edge: GAAGG
# -> In edge: TAGAA
# -> In edge: AAGAA
# -> In edge: GAGAA
# -> In edge: CAGAA
# Vertex: GGTTT, coverage: 374
# -> Out edge: GTTTT
# -> Out edge: GTTTG
# -> Out edge: GTTTA
# -> Out edge: GTTTC
# -> In edge: CGGTT
# -> In edge: TGGTT
# -> In edge: GGGTT
# -> In edge: AGGTT
# Vertex: TAACG, coverage: 9
# -> Out edge: AACGG
# -> Out edge: AACGT
# -> Out edge: AACGA
# -> In edge: TTAAC
# -> In edge: GTAAC
# -> In edge: CTAAC
# -> In edge: ATAAC
# Vertex: GGGAT, coverage: 415
# -> Out edge: GGATT
# -> Out edge: GGATA
# -> Out edge: GGATC
# -> Out edge: GGATG
# -> In edge: GGGGA
# -> In edge: AGGGA
# -> In edge: CGGGA
# -> In edge: TGGGA
# Vertex: TGGAT, coverage: 569
# -> Out edge: GGATA
# -> Out edge: GGATC
# -> Out edge: GGATG
# -> Out edge: GGATT
# -> In edge: TTGGA
# -> In edge: ATGGA
# -> In edge: CTGGA
# -> In edge: GTGGA
# Vertex: GCACG, coverage: 7
# -> Out edge: CACGA
# -> Out edge: CACGT
# -> Out edge: CACGC
# -> Out edge: CACGG
# -> In edge: CGCAC
# -> In edge: AGCAC
# -> In edge: TGCAC
# -> In edge: GGCAC
# Vertex: CGAGC, coverage: 100
# -> Out edge: GAGCG
# -> Out edge: GAGCT
# -> Out edge: GAGCC
# -> Out edge: GAGCA
# -> In edge: ACGAG
# -> In edge: GCGAG
# -> In edge: CCGAG
# -> In edge: TCGAG
# Vertex: TTGAT, coverage: 394
# -> Out edge: TGATC
# -> Out edge: TGATT
# -> Out edge: TGATG
# -> Out edge: TGATA
# -> In edge: TTTGA
# -> In edge: ATTGA
# -> In edge: CTTGA
# -> In edge: GTTGA
# Vertex: GGGCC, coverage: 110
# -> Out edge: GGCCG
# -> Out edge: GGCCT
# -> Out edge: GGCCC
# -> Out edge: GGCCA
# -> In edge: GGGGC
# -> In edge: CGGGC
# -> In edge: AGGGC
# -> In edge: TGGGC
# Vertex: GGAAG, coverage: 412
# -> Out edge: GAAGC
# -> Out edge: GAAGA
# -> Out edge: GAAGT
# -> Out edge: GAAGG
# -> In edge: CGGAA
# -> In edge: GGGAA
# -> In edge: TGGAA
# -> In edge: AGGAA
# Vertex: TAGAC, coverage: 209
# -> Out edge: AGACT
# -> Out edge: AGACG
# -> Out edge: AGACA
# -> Out edge: AGACC
# -> In edge: ATAGA
# -> In edge: GTAGA
# -> In edge: CTAGA
# -> In edge: TTAGA
# Vertex: CATTG, coverage: 289
# -> Out edge: ATTGA
# -> Out edge: ATTGG
# -> Out edge: ATTGC
# -> Out edge: ATTGT
# -> In edge: CCATT
# -> In edge: TCATT
# -> In edge: ACATT
# -> In edge: GCATT
# Vertex: GCCTG, coverage: 566
# -> Out edge: CCTGA
# -> Out edge: CCTGG
# -> Out edge: CCTGT
# -> Out edge: CCTGC
# -> In edge: GGCCT
# -> In edge: TGCCT
# -> In edge: CGCCT
# -> In edge: AGCCT
# Vertex: AAAGC, coverage: 575
# -> Out edge: AAGCA
# -> Out edge: AAGCG
# -> Out edge: AAGCT
# -> Out edge: AAGCC
# -> In edge: TAAAG
# -> In edge: CAAAG
# -> In edge: AAAAG
# -> In edge: GAAAG
# Vertex: CCTAG, coverage: 383
# -> Out edge: CTAGT
# -> Out edge: CTAGG
# -> Out edge: CTAGC
# -> Out edge: CTAGA
# -> In edge: TCCTA
# -> In edge: CCCTA
# -> In edge: GCCTA
# -> In edge: ACCTA
# Vertex: CCACT, coverage: 200
# -> Out edge: CACTT
# -> Out edge: CACTA
# -> Out edge: CACTG
# -> Out edge: CACTC
# -> In edge: CCCAC
# -> In edge: TCCAC
# -> In edge: ACCAC
# -> In edge: GCCAC
# Vertex: CTCCT, coverage: 374
# -> Out edge: TCCTA
# -> Out edge: TCCTT
# -> Out edge: TCCTC
# -> Out edge: TCCTG
# -> In edge: GCTCC
# -> In edge: CCTCC
# -> In edge: TCTCC
# -> In edge: ACTCC
# Vertex: ATAAG, coverage: 387
# -> Out edge: TAAGG
# -> Out edge: TAAGT
# -> Out edge: TAAGC
# -> Out edge: TAAGA
# -> In edge: CATAA
# -> In edge: AATAA
# -> In edge: TATAA
# -> In edge: GATAA
# Vertex: GTCGC, coverage: 15
# -> Out edge: TCGCC
# -> Out edge: TCGCA
# -> Out edge: TCGCT
# -> Out edge: TCGCG
# -> In edge: CGTCG
# -> In edge: GGTCG
# -> In edge: AGTCG
# Vertex: CATAC, coverage: 299
# -> Out edge: ATACC
# -> Out edge: ATACA
# -> Out edge: ATACG
# -> Out edge: ATACT
# -> In edge: GCATA
# -> In edge: CCATA
# -> In edge: TCATA
# -> In edge: ACATA
# Vertex: CTGTA, coverage: 275
# -> Out edge: TGTAT
# -> Out edge: TGTAG
# -> Out edge: TGTAC
# -> Out edge: TGTAA
# -> In edge: ACTGT
# -> In edge: CCTGT
# -> In edge: GCTGT
# -> In edge: TCTGT
# Vertex: AGAAT, coverage: 399
# -> Out edge: GAATA
# -> Out edge: GAATC
# -> Out edge: GAATT
# -> Out edge: GAATG
# -> In edge: TAGAA
# -> In edge: AAGAA
# -> In edge: GAGAA
# -> In edge: CAGAA
# Vertex: TTGTT, coverage: 750
# -> Out edge: TGTTT
# -> Out edge: TGTTA
# -> Out edge: TGTTC
# -> Out edge: TGTTG
# -> In edge: TTTGT
# -> In edge: CTTGT
# -> In edge: GTTGT
# -> In edge: ATTGT
# Vertex: TACTC, coverage: 103
# -> Out edge: ACTCG
# -> Out edge: ACTCA
# -> Out edge: ACTCT
# -> Out edge: ACTCC
# -> In edge: TTACT
# -> In edge: GTACT
# -> In edge: ATACT
# Vertex: TTTTG, coverage: 382
# -> Out edge: TTTGT
# -> Out edge: TTTGA
# -> Out edge: TTTGC
# -> Out edge: TTTGG
# -> In edge: TTTTT
# -> In edge: CTTTT
# -> In edge: ATTTT
# -> In edge: GTTTT
# Vertex: CAATG, coverage: 384
# -> Out edge: AATGC
# -> Out edge: AATGT
# -> Out edge: AATGG
# -> Out edge: AATGA
# -> In edge: TCAAT
# -> In edge: GCAAT
# -> In edge: ACAAT
# -> In edge: CCAAT
# Vertex: CCCCA, coverage: 933
# -> Out edge: CCCAC
# -> Out edge: CCCAT
# -> Out edge: CCCAG
# -> Out edge: CCCAA
# -> In edge: GCCCC
# -> In edge: TCCCC
# -> In edge: CCCCC
# -> In edge: ACCCC
# Vertex: TTGGG, coverage: 298
# -> Out edge: TGGGG
# -> Out edge: TGGGT
# -> Out edge: TGGGC
# -> Out edge: TGGGA
# -> In edge: ATTGG
# -> In edge: GTTGG
# -> In edge: TTTGG
# -> In edge: CTTGG
# Vertex: CGCCG, coverage: 194
# -> Out edge: GCCGG
# -> Out edge: GCCGT
# -> Out edge: GCCGC
# -> Out edge: GCCGA
# -> In edge: GCGCC
# -> In edge: CCGCC
# -> In edge: TCGCC
# -> In edge: ACGCC
# Vertex: CGTGA, coverage: 11
# -> Out edge: GTGAA
# -> Out edge: GTGAT
# -> Out edge: GTGAG
# -> In edge: CCGTG
# -> In edge: GCGTG
# -> In edge: ACGTG
# Vertex: CTGGA, coverage: 637
# -> Out edge: TGGAT
# -> Out edge: TGGAG
# -> Out edge: TGGAC
# -> Out edge: TGGAA
# -> In edge: ACTGG
# -> In edge: CCTGG
# -> In edge: GCTGG
# -> In edge: TCTGG
# Vertex: GCGGA, coverage: 104
# -> Out edge: CGGAG
# -> Out edge: CGGAA
# -> Out edge: CGGAC
# -> Out edge: CGGAT
# -> In edge: GGCGG
# -> In edge: AGCGG
# -> In edge: CGCGG
# -> In edge: TGCGG
# Vertex: ATGGG, coverage: 198
# -> Out edge: TGGGT
# -> Out edge: TGGGG
# -> Out edge: TGGGC
# -> Out edge: TGGGA
# -> In edge: CATGG
# -> In edge: GATGG
# -> In edge: AATGG
# -> In edge: TATGG
# Vertex: CCTAA, coverage: 110
# -> Out edge: CTAAC
# -> Out edge: CTAAG
# -> Out edge: CTAAT
# -> Out edge: CTAAA
# -> In edge: TCCTA
# -> In edge: CCCTA
# -> In edge: GCCTA
# -> In edge: ACCTA
# Vertex: AAAGA, coverage: 1109
# -> Out edge: AAGAA
# -> Out edge: AAGAT
# -> Out edge: AAGAG
# -> Out edge: AAGAC
# -> In edge: TAAAG
# -> In edge: CAAAG
# -> In edge: AAAAG
# -> In edge: GAAAG
# Vertex: TAGCC, coverage: 10
# -> Out edge: AGCCG
# -> Out edge: AGCCA
# -> Out edge: AGCCC
# -> Out edge: AGCCT
# -> In edge: ATAGC
# -> In edge: GTAGC
# -> In edge: CTAGC
# -> In edge: TTAGC
# Vertex: CATCC, coverage: 288
# -> Out edge: ATCCC
# -> Out edge: ATCCG
# -> Out edge: ATCCT
# -> Out edge: ATCCA
# -> In edge: TCATC
# -> In edge: GCATC
# -> In edge: ACATC
# -> In edge: CCATC
# Vertex: GAAGA, coverage: 666
# -> Out edge: AAGAA
# -> Out edge: AAGAT
# -> Out edge: AAGAC
# -> Out edge: AAGAG
# -> In edge: TGAAG
# -> In edge: AGAAG
# -> In edge: GGAAG
# -> In edge: CGAAG
# Vertex: AAACA, coverage: 662
# -> Out edge: AACAG
# -> Out edge: AACAA
# -> Out edge: AACAT
# -> Out edge: AACAC
# -> In edge: AAAAC
# -> In edge: CAAAC
# -> In edge: GAAAC
# -> In edge: TAAAC
# Vertex: AAACG, coverage: 472
# -> Out edge: AACGC
# -> Out edge: AACGG
# -> Out edge: AACGT
# -> Out edge: AACGA
# -> In edge: AAAAC
# -> In edge: CAAAC
# -> In edge: GAAAC
# -> In edge: TAAAC
# Vertex: AACCC, coverage: 473
# -> Out edge: ACCCC
# -> Out edge: ACCCT
# -> Out edge: ACCCA
# -> Out edge: ACCCG
# -> In edge: AAACC
# -> In edge: CAACC
# -> In edge: GAACC
# -> In edge: TAACC
# Vertex: CGTTG, coverage: 283
# -> Out edge: GTTGC
# -> Out edge: GTTGA
# -> Out edge: GTTGT
# -> Out edge: GTTGG
# -> In edge: TCGTT
# -> In edge: GCGTT
# -> In edge: ACGTT
# -> In edge: CCGTT
# Vertex: TAAAA, coverage: 568
# -> Out edge: AAAAC
# -> Out edge: AAAAT
# -> Out edge: AAAAG
# -> Out edge: AAAAA
# -> In edge: TTAAA
# -> In edge: ATAAA
# -> In edge: CTAAA
# -> In edge: GTAAA
# Vertex: GTTTA, coverage: 374
# -> Out edge: TTTAG
# -> Out edge: TTTAA
# -> Out edge: TTTAC
# -> Out edge: TTTAT
# -> In edge: TGTTT
# -> In edge: AGTTT
# -> In edge: GGTTT
# -> In edge: CGTTT
# Vertex: GTTAA, coverage: 109
# -> Out edge: TTAAC
# -> Out edge: TTAAT
# -> Out edge: TTAAG
# -> Out edge: TTAAA
# -> In edge: TGTTA
# -> In edge: GGTTA
# -> In edge: CGTTA
# Vertex: GTAGT, coverage: 474
# -> Out edge: TAGTC
# -> Out edge: TAGTG
# -> Out edge: TAGTA
# -> Out edge: TAGTT
# -> In edge: AGTAG
# -> In edge: GGTAG
# -> In edge: TGTAG
# -> In edge: CGTAG
# Vertex: GCTCA, coverage: 97
# -> Out edge: CTCAG
# -> Out edge: CTCAA
# -> Out edge: CTCAC
# -> Out edge: CTCAT
# -> In edge: TGCTC
# -> In edge: GGCTC
# -> In edge: AGCTC
# Vertex: TAGGG, coverage: 289
# -> Out edge: AGGGA
# -> Out edge: AGGGG
# -> Out edge: AGGGT
# -> Out edge: AGGGC
# -> In edge: GTAGG
# -> In edge: TTAGG
# -> In edge: CTAGG
# -> In edge: ATAGG
# Vertex: GATGG, coverage: 395
# -> Out edge: ATGGA
# -> Out edge: ATGGG
# -> Out edge: ATGGT
# -> Out edge: ATGGC
# -> In edge: AGATG
# -> In edge: TGATG
# -> In edge: GGATG
# -> In edge: CGATG
# Vertex: TCCAA, coverage: 927
# -> Out edge: CCAAG
# -> Out edge: CCAAC
# -> Out edge: CCAAA
# -> Out edge: CCAAT
# -> In edge: CTCCA
# -> In edge: TTCCA
# -> In edge: GTCCA
# -> In edge: ATCCA
# Vertex: CTAAC, coverage: 197
# -> Out edge: TAACC
# -> Out edge: TAACA
# -> Out edge: TAACT
# -> Out edge: TAACG
# -> In edge: TCTAA
# -> In edge: ACTAA
# -> In edge: CCTAA
# -> In edge: GCTAA
# Vertex: CCGAC, coverage: 104
# -> Out edge: CGACA
# -> Out edge: CGACG
# -> Out edge: CGACT
# -> Out edge: CGACC
# -> In edge: ACCGA
# -> In edge: CCCGA
# -> In edge: TCCGA
# -> In edge: GCCGA
# Vertex: GACCG, coverage: 6
# -> Out edge: ACCGA
# -> Out edge: ACCGT
# -> Out edge: ACCGG
# -> Out edge: ACCGC
# -> In edge: TGACC
# -> In edge: AGACC
# Vertex: TCATC, coverage: 95
# -> Out edge: CATCC
# -> Out edge: CATCG
# -> In edge: ATCAT
# -> In edge: GTCAT
# -> In edge: TTCAT
# -> In edge: CTCAT
# Vertex: ATCAC, coverage: 12
# -> Out edge: TCACG
# -> Out edge: TCACA
# -> Out edge: TCACT
# -> Out edge: TCACC
# -> In edge: CATCA
# -> In edge: AATCA
# -> In edge: GATCA
# -> In edge: TATCA
# Vertex: TCCTC, coverage: 381
# -> Out edge: CCTCG
# -> Out edge: CCTCC
# -> Out edge: CCTCA
# -> Out edge: CCTCT
# -> In edge: TTCCT
# -> In edge: CTCCT
# -> In edge: GTCCT
# -> In edge: ATCCT
# Vertex: ACTAG, coverage: 277
# -> Out edge: CTAGC
# -> Out edge: CTAGG
# -> Out edge: CTAGT
# -> Out edge: CTAGA
# -> In edge: CACTA
# -> In edge: AACTA
# -> In edge: TACTA
# -> In edge: GACTA
# Vertex: ATATA, coverage: 291
# -> Out edge: TATAT
# -> Out edge: TATAC
# -> Out edge: TATAA
# -> Out edge: TATAG
# -> In edge: AATAT
# -> In edge: CATAT
# -> In edge: TATAT
# -> In edge: GATAT
# Vertex: TGATT, coverage: 383
# -> Out edge: GATTA
# -> Out edge: GATTG
# -> Out edge: GATTT
# -> Out edge: GATTC
# -> In edge: GTGAT
# -> In edge: ATGAT
# -> In edge: TTGAT
# -> In edge: CTGAT
# Vertex: CCTCG, coverage: 196
# -> Out edge: CTCGT
# -> Out edge: CTCGA
# -> Out edge: CTCGC
# -> Out edge: CTCGG
# -> In edge: ACCTC
# -> In edge: TCCTC
# -> In edge: CCCTC
# -> In edge: GCCTC
# Vertex: AGGAA, coverage: 664
# -> Out edge: GGAAC
# -> Out edge: GGAAA
# -> Out edge: GGAAG
# -> Out edge: GGAAT
# -> In edge: TAGGA
# -> In edge: GAGGA
# -> In edge: AAGGA
# -> In edge: CAGGA
# Vertex: ATAAA, coverage: 393
# -> Out edge: TAAAA
# -> Out edge: TAAAG
# -> Out edge: TAAAT
# -> Out edge: TAAAC
# -> In edge: CATAA
# -> In edge: AATAA
# -> In edge: TATAA
# -> In edge: GATAA
# Vertex: AGGCC, coverage: 519
# -> Out edge: GGCCA
# -> Out edge: GGCCT
# -> Out edge: GGCCC
# -> Out edge: GGCCG
# -> In edge: CAGGC
# -> In edge: TAGGC
# -> In edge: GAGGC
# -> In edge: AAGGC
# Vertex: ATAAC, coverage: 657
# -> Out edge: TAACC
# -> Out edge: TAACA
# -> Out edge: TAACT
# -> Out edge: TAACG
# -> In edge: CATAA
# -> In edge: AATAA
# -> In edge: TATAA
# -> In edge: GATAA
# Vertex: CGGGG, coverage: 234
# -> Out edge: GGGGA
# -> Out edge: GGGGC
# -> Out edge: GGGGG
# -> Out edge: GGGGT
# -> In edge: TCGGG
# -> In edge: CCGGG
# -> In edge: ACGGG
# -> In edge: GCGGG
# Vertex: GTTGA, coverage: 482
# -> Out edge: TTGAA
# -> Out edge: TTGAT
# -> Out edge: TTGAG
# -> Out edge: TTGAC
# -> In edge: CGTTG
# -> In edge: AGTTG
# -> In edge: GGTTG
# -> In edge: TGTTG
# Vertex: GGTTA, coverage: 14
# -> Out edge: GTTAT
# -> Out edge: GTTAA
# -> Out edge: GTTAC
# -> Out edge: GTTAG
# -> In edge: TGGTT
# -> In edge: GGGTT
# -> In edge: AGGTT
# Vertex: TCTTA, coverage: 196
# -> Out edge: CTTAC
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> Out edge: CTTAT
# -> In edge: TTCTT
# -> In edge: GTCTT
# -> In edge: CTCTT
# Vertex: TCACT, coverage: 45
# -> Out edge: CACTT
# -> Out edge: CACTA
# -> Out edge: CACTG
# -> Out edge: CACTC
# -> In edge: ATCAC
# -> In edge: CTCAC
# -> In edge: TTCAC
# Vertex: CCACC, coverage: 539
# -> Out edge: CACCA
# -> Out edge: CACCG
# -> Out edge: CACCT
# -> Out edge: CACCC
# -> In edge: CCCAC
# -> In edge: TCCAC
# -> In edge: ACCAC
# -> In edge: GCCAC
# Vertex: GCGCT, coverage: 194
# -> Out edge: CGCTA
# -> Out edge: CGCTC
# -> Out edge: CGCTG
# -> In edge: TGCGC
# -> In edge: GGCGC
# -> In edge: CGCGC
# -> In edge: AGCGC
# Vertex: CCATT, coverage: 17
# -> Out edge: CATTC
# -> Out edge: CATTT
# -> Out edge: CATTA
# -> Out edge: CATTG
# -> In edge: CCCAT
# -> In edge: GCCAT
# -> In edge: TCCAT
# -> In edge: ACCAT
# Vertex: GCCCC, coverage: 474
# -> Out edge: CCCCA
# -> Out edge: CCCCC
# -> Out edge: CCCCG
# -> Out edge: CCCCT
# -> In edge: TGCCC
# -> In edge: CGCCC
# -> In edge: GGCCC
# -> In edge: AGCCC
# Vertex: GTATA, coverage: 289
# -> Out edge: TATAC
# -> Out edge: TATAT
# -> Out edge: TATAA
# -> Out edge: TATAG
# -> In edge: AGTAT
# -> In edge: TGTAT
# -> In edge: GGTAT
# -> In edge: CGTAT
# Vertex: CGGCC, coverage: 18
# -> Out edge: GGCCG
# -> Out edge: GGCCA
# -> Out edge: GGCCC
# -> Out edge: GGCCT
# -> In edge: CCGGC
# -> In edge: TCGGC
# -> In edge: GCGGC
# -> In edge: ACGGC
# Vertex: AAGTA, coverage: 197
# -> Out edge: AGTAC
# -> Out edge: AGTAG
# -> Out edge: AGTAT
# -> Out edge: AGTAA
# -> In edge: CAAGT
# -> In edge: TAAGT
# -> In edge: GAAGT
# -> In edge: AAAGT
# Vertex: TTAAT, coverage: 205
# -> Out edge: TAATG
# -> Out edge: TAATC
# -> Out edge: TAATA
# -> Out edge: TAATT
# -> In edge: ATTAA
# -> In edge: TTTAA
# -> In edge: CTTAA
# -> In edge: GTTAA
# Vertex: ACATT, coverage: 458
# -> Out edge: CATTC
# -> Out edge: CATTT
# -> Out edge: CATTA
# -> Out edge: CATTG
# -> In edge: AACAT
# -> In edge: GACAT
# -> In edge: CACAT
# -> In edge: TACAT
# Vertex: GACCT, coverage: 560
# -> Out edge: ACCTG
# -> Out edge: ACCTC
# -> Out edge: ACCTA
# -> Out edge: ACCTT
# -> In edge: GGACC
# -> In edge: TGACC
# -> In edge: AGACC
# -> In edge: CGACC
# Vertex: ACCCA, coverage: 925
# -> Out edge: CCCAC
# -> Out edge: CCCAT
# -> Out edge: CCCAG
# -> Out edge: CCCAA
# -> In edge: AACCC
# -> In edge: TACCC
# -> In edge: GACCC
# -> In edge: CACCC
# Vertex: CTGTG, coverage: 101
# -> Out edge: TGTGT
# -> Out edge: TGTGC
# -> Out edge: TGTGA
# -> Out edge: TGTGG
# -> In edge: ACTGT
# -> In edge: CCTGT
# -> In edge: TCTGT
# -> In edge: GCTGT
# Vertex: GCTAC, coverage: 8
# -> Out edge: CTACA
# -> Out edge: CTACG
# -> Out edge: CTACC
# -> In edge: CGCTA
# -> In edge: GGCTA
# -> In edge: TGCTA
# -> In edge: AGCTA
# Vertex: AGACA, coverage: 596
# -> Out edge: GACAA
# -> Out edge: GACAC
# -> Out edge: GACAT
# -> Out edge: GACAG
# -> In edge: GAGAC
# -> In edge: TAGAC
# -> In edge: CAGAC
# -> In edge: AAGAC
# Vertex: TGTGA, coverage: 382
# -> Out edge: GTGAA
# -> Out edge: GTGAT
# -> Out edge: GTGAG
# -> Out edge: GTGAC
# -> In edge: CTGTG
# -> In edge: TTGTG
# -> In edge: ATGTG
# -> In edge: GTGTG
# Vertex: ACTAA, coverage: 106
# -> Out edge: CTAAA
# -> Out edge: CTAAC
# -> Out edge: CTAAT
# -> Out edge: CTAAG
# -> In edge: CACTA
# -> In edge: AACTA
# -> In edge: TACTA
# -> In edge: GACTA
# Vertex: GAACA, coverage: 464
# -> Out edge: AACAG
# -> Out edge: AACAA
# -> Out edge: AACAT
# -> Out edge: AACAC
# -> In edge: TGAAC
# -> In edge: CGAAC
# -> In edge: GGAAC
# -> In edge: AGAAC
# Vertex: AGGAT, coverage: 940
# -> Out edge: GGATT
# -> Out edge: GGATA
# -> Out edge: GGATC
# -> Out edge: GGATG
# -> In edge: TAGGA
# -> In edge: AAGGA
# -> In edge: GAGGA
# -> In edge: CAGGA
# Vertex: ACCAT, coverage: 13
# -> Out edge: CCATT
# -> Out edge: CCATG
# -> Out edge: CCATA
# -> Out edge: CCATC
# -> In edge: GACCA
# -> In edge: CACCA
# -> In edge: TACCA
# -> In edge: AACCA
# Vertex: TAGCA, coverage: 192
# -> Out edge: AGCAG
# -> Out edge: AGCAA
# -> Out edge: AGCAT
# -> Out edge: AGCAC
# -> In edge: ATAGC
# -> In edge: GTAGC
# -> In edge: CTAGC
# -> In edge: TTAGC
# Vertex: TCTGT, coverage: 19
# -> Out edge: CTGTA
# -> Out edge: CTGTC
# -> Out edge: CTGTG
# -> Out edge: CTGTT
# -> In edge: ATCTG
# -> In edge: GTCTG
# -> In edge: CTCTG
# -> In edge: TTCTG
# Vertex: TTGAG, coverage: 569
# -> Out edge: TGAGG
# -> Out edge: TGAGA
# -> Out edge: TGAGT
# -> Out edge: TGAGC
# -> In edge: ATTGA
# -> In edge: TTTGA
# -> In edge: CTTGA
# -> In edge: GTTGA
# Vertex: CAGAT, coverage: 109
# -> Out edge: AGATG
# -> Out edge: AGATT
# -> Out edge: AGATC
# -> In edge: ACAGA
# -> In edge: TCAGA
# -> In edge: CCAGA
# -> In edge: GCAGA
# Vertex: CTGCC, coverage: 244
# -> Out edge: TGCCC
# -> Out edge: TGCCA
# -> Out edge: TGCCT
# -> In edge: TCTGC
# -> In edge: ACTGC
# -> In edge: CCTGC
# -> In edge: GCTGC
# Vertex: GGTAG, coverage: 251
# -> Out edge: GTAGT
# -> Out edge: GTAGG
# -> Out edge: GTAGA
# -> Out edge: GTAGC
# -> In edge: AGGTA
# -> In edge: TGGTA
# -> In edge: CGGTA
# -> In edge: GGGTA
# Vertex: ATGGC, coverage: 198
# -> Out edge: TGGCG
# -> Out edge: TGGCA
# -> Out edge: TGGCT
# -> Out edge: TGGCC
# -> In edge: CATGG
# -> In edge: GATGG
# -> In edge: AATGG
# -> In edge: TATGG
# Vertex: CAAGC, coverage: 282
# -> Out edge: AAGCA
# -> Out edge: AAGCG
# -> Out edge: AAGCT
# -> Out edge: AAGCC
# -> In edge: ACAAG
# -> In edge: TCAAG
# -> In edge: CCAAG
# -> In edge: GCAAG
# Vertex: GCCAC, coverage: 165
# -> Out edge: CCACA
# -> Out edge: CCACG
# -> Out edge: CCACC
# -> Out edge: CCACT
# -> In edge: GGCCA
# -> In edge: CGCCA
# -> In edge: AGCCA
# -> In edge: TGCCA
# Vertex: GGGCG, coverage: 107
# -> Out edge: GGCGT
# -> Out edge: GGCGG
# -> Out edge: GGCGC
# -> Out edge: GGCGA
# -> In edge: GGGGC
# -> In edge: CGGGC
# -> In edge: AGGGC
# -> In edge: TGGGC
# Vertex: GTAGG, coverage: 154
# -> Out edge: TAGGT
# -> Out edge: TAGGC
# -> Out edge: TAGGA
# -> Out edge: TAGGG
# -> In edge: AGTAG
# -> In edge: GGTAG
# -> In edge: TGTAG
# -> In edge: CGTAG
# Vertex: TCTGG, coverage: 327
# -> Out edge: CTGGT
# -> Out edge: CTGGG
# -> Out edge: CTGGC
# -> Out edge: CTGGA
# -> In edge: CTCTG
# -> In edge: GTCTG
# -> In edge: ATCTG
# -> In edge: TTCTG
# Vertex: ACCCG, coverage: 101
# -> Out edge: CCCGA
# -> Out edge: CCCGT
# -> Out edge: CCCGG
# -> Out edge: CCCGC
# -> In edge: AACCC
# -> In edge: TACCC
# -> In edge: CACCC
# -> In edge: GACCC
# Vertex: CGTTC, coverage: 105
# -> Out edge: GTTCA
# -> Out edge: GTTCG
# -> Out edge: GTTCC
# -> Out edge: GTTCT
# -> In edge: TCGTT
# -> In edge: CCGTT
# -> In edge: ACGTT
# -> In edge: GCGTT
# Vertex: TCTTG, coverage: 406
# -> Out edge: CTTGT
# -> Out edge: CTTGC
# -> Out edge: CTTGA
# -> Out edge: CTTGG
# -> In edge: ATCTT
# -> In edge: TTCTT
# -> In edge: GTCTT
# -> In edge: CTCTT
# Vertex: TTACA, coverage: 104
# -> Out edge: TACAC
# -> Out edge: TACAT
# -> Out edge: TACAG
# -> Out edge: TACAA
# -> In edge: CTTAC
# -> In edge: TTTAC
# -> In edge: ATTAC
# -> In edge: GTTAC
# Vertex: TTCGC, coverage: 8
# -> Out edge: TCGCC
# -> Out edge: TCGCT
# -> Out edge: TCGCA
# -> Out edge: TCGCG
# -> In edge: TTTCG
# -> In edge: ATTCG
# -> In edge: CTTCG
# -> In edge: GTTCG
# Vertex: CCTTA, coverage: 197
# -> Out edge: CTTAC
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> Out edge: CTTAT
# -> In edge: GCCTT
# -> In edge: TCCTT
# -> In edge: CCCTT
# -> In edge: ACCTT
# Vertex: CGTGC, coverage: 285
# -> Out edge: GTGCT
# -> Out edge: GTGCG
# -> Out edge: GTGCC
# -> Out edge: GTGCA
# -> In edge: CCGTG
# -> In edge: GCGTG
# -> In edge: TCGTG
# -> In edge: ACGTG
# Vertex: CACAC, coverage: 286
# -> Out edge: ACACT
# -> Out edge: ACACG
# -> Out edge: ACACA
# -> Out edge: ACACC
# -> In edge: GCACA
# -> In edge: CCACA
# -> In edge: ACACA
# -> In edge: TCACA
# Vertex: GTCAT, coverage: 192
# -> Out edge: TCATT
# -> Out edge: TCATG
# -> Out edge: TCATA
# -> Out edge: TCATC
# -> In edge: AGTCA
# -> In edge: GGTCA
# -> In edge: TGTCA
# Vertex: CCTCA, coverage: 103
# -> Out edge: CTCAC
# -> Out edge: CTCAA
# -> Out edge: CTCAG
# -> Out edge: CTCAT
# -> In edge: ACCTC
# -> In edge: TCCTC
# -> In edge: CCCTC
# -> In edge: GCCTC
# Vertex: GATCT, coverage: 416
# -> Out edge: ATCTT
# -> Out edge: ATCTG
# -> Out edge: ATCTA
# -> Out edge: ATCTC
# -> In edge: TGATC
# -> In edge: CGATC
# -> In edge: GGATC
# -> In edge: AGATC
# Vertex: TCTCC, coverage: 379
# -> Out edge: CTCCA
# -> Out edge: CTCCC
# -> Out edge: CTCCG
# -> Out edge: CTCCT
# -> In edge: TTCTC
# -> In edge: CTCTC
# -> In edge: ATCTC
# -> In edge: GTCTC
# Vertex: TATCA, coverage: 94
# -> Out edge: ATCAT
# -> Out edge: ATCAC
# -> Out edge: ATCAG
# -> In edge: GTATC
# -> In edge: TTATC
# Vertex: AAATC, coverage: 16
# -> Out edge: AATCC
# -> Out edge: AATCA
# -> Out edge: AATCG
# -> Out edge: AATCT
# -> In edge: TAAAT
# -> In edge: CAAAT
# -> In edge: AAAAT
# -> In edge: GAAAT
# Vertex: GTCTC, coverage: 280
# -> Out edge: TCTCA
# -> Out edge: TCTCG
# -> Out edge: TCTCT
# -> Out edge: TCTCC
# -> In edge: CGTCT
# -> In edge: GGTCT
# -> In edge: TGTCT
# -> In edge: AGTCT
# Vertex: CGATA, coverage: 371
# -> Out edge: GATAT
# -> Out edge: GATAG
# -> Out edge: GATAC
# -> Out edge: GATAA
# -> In edge: GCGAT
# -> In edge: ACGAT
# -> In edge: CCGAT
# -> In edge: TCGAT
# Vertex: GCAGT, coverage: 387
# -> Out edge: CAGTA
# -> Out edge: CAGTG
# -> Out edge: CAGTT
# -> Out edge: CAGTC
# -> In edge: AGCAG
# -> In edge: CGCAG
# -> In edge: TGCAG
# -> In edge: GGCAG
# Vertex: TCAAG, coverage: 198
# -> Out edge: CAAGT
# -> Out edge: CAAGG
# -> Out edge: CAAGA
# -> Out edge: CAAGC
# -> In edge: TTCAA
# -> In edge: GTCAA
# -> In edge: CTCAA
# -> In edge: ATCAA
# Vertex: AGCAA, coverage: 477
# -> Out edge: GCAAA
# -> Out edge: GCAAT
# -> Out edge: GCAAC
# -> Out edge: GCAAG
# -> In edge: AAGCA
# -> In edge: TAGCA
# -> In edge: CAGCA
# -> In edge: GAGCA
# Vertex: GTCTT, coverage: 284
# -> Out edge: TCTTG
# -> Out edge: TCTTT
# -> Out edge: TCTTA
# -> Out edge: TCTTC
# -> In edge: CGTCT
# -> In edge: GGTCT
# -> In edge: TGTCT
# -> In edge: AGTCT
# Vertex: TGAGG, coverage: 862
# -> Out edge: GAGGT
# -> Out edge: GAGGC
# -> Out edge: GAGGG
# -> Out edge: GAGGA
# -> In edge: CTGAG
# -> In edge: GTGAG
# -> In edge: TTGAG
# -> In edge: ATGAG
# Vertex: TCCTG, coverage: 337
# -> Out edge: CCTGA
# -> Out edge: CCTGG
# -> Out edge: CCTGT
# -> Out edge: CCTGC
# -> In edge: TTCCT
# -> In edge: CTCCT
# -> In edge: GTCCT
# -> In edge: ATCCT
# Vertex: GTCGT, coverage: 281
# -> Out edge: TCGTG
# -> Out edge: TCGTT
# -> Out edge: TCGTC
# -> Out edge: TCGTA
# -> In edge: CGTCG
# -> In edge: GGTCG
# -> In edge: TGTCG
# -> In edge: AGTCG
# Vertex: TCGGT, coverage: 186
# -> Out edge: CGGTG
# -> Out edge: CGGTC
# -> Out edge: CGGTT
# -> In edge: ATCGG
# -> In edge: GTCGG
# -> In edge: TTCGG
# -> In edge: CTCGG
# Vertex: AAGTT, coverage: 562
# -> Out edge: AGTTA
# -> Out edge: AGTTT
# -> Out edge: AGTTG
# -> Out edge: AGTTC
# -> In edge: CAAGT
# -> In edge: TAAGT
# -> In edge: GAAGT
# -> In edge: AAAGT
# Vertex: TGTTA, coverage: 194
# -> Out edge: GTTAT
# -> Out edge: GTTAA
# -> Out edge: GTTAG
# -> Out edge: GTTAC
# -> In edge: ATGTT
# -> In edge: TTGTT
# -> In edge: CTGTT
# -> In edge: GTGTT
# Vertex: CCCTC, coverage: 6
# -> Out edge: CCTCA
# -> Out edge: CCTCC
# -> Out edge: CCTCG
# -> Out edge: CCTCT
# -> In edge: GCCCT
# -> In edge: CCCCT
# Vertex: AGGGT, coverage: 474
# -> Out edge: GGGTC
# -> Out edge: GGGTG
# -> Out edge: GGGTT
# -> Out edge: GGGTA
# -> In edge: TAGGG
# -> In edge: CAGGG
# -> In edge: GAGGG
# -> In edge: AAGGG
# Vertex: AGCCC, coverage: 482
# -> Out edge: GCCCT
# -> Out edge: GCCCC
# -> Out edge: GCCCG
# -> Out edge: GCCCA
# -> In edge: GAGCC
# -> In edge: TAGCC
# -> In edge: CAGCC
# -> In edge: AAGCC
# Vertex: TGAAT, coverage: 106
# -> Out edge: GAATA
# -> Out edge: GAATC
# -> Out edge: GAATT
# -> Out edge: GAATG
# -> In edge: CTGAA
# -> In edge: GTGAA
# -> In edge: TTGAA
# -> In edge: ATGAA
# Vertex: ATGAA, coverage: 202
# -> Out edge: TGAAG
# -> Out edge: TGAAC
# -> Out edge: TGAAA
# -> Out edge: TGAAT
# -> In edge: CATGA
# -> In edge: TATGA
# -> In edge: GATGA
# -> In edge: AATGA
# Vertex: CACGC, coverage: 108
# -> Out edge: ACGCT
# -> Out edge: ACGCG
# -> Out edge: ACGCA
# -> Out edge: ACGCC
# -> In edge: TCACG
# -> In edge: CCACG
# -> In edge: GCACG
# -> In edge: ACACG
# Vertex: GTGGG, coverage: 467
# -> Out edge: TGGGG
# -> Out edge: TGGGT
# -> Out edge: TGGGC
# -> Out edge: TGGGA
# -> In edge: TGTGG
# -> In edge: GGTGG
# -> In edge: CGTGG
# -> In edge: AGTGG
# Vertex: GTACT, coverage: 97
# -> Out edge: TACTA
# -> Out edge: TACTT
# -> Out edge: TACTC
# -> Out edge: TACTG
# -> In edge: AGTAC
# -> In edge: CGTAC
# -> In edge: TGTAC
# -> In edge: GGTAC
# Vertex: TTTGC, coverage: 471
# -> Out edge: TTGCA
# -> Out edge: TTGCT
# -> Out edge: TTGCC
# -> Out edge: TTGCG
# -> In edge: TTTTG
# -> In edge: GTTTG
# -> In edge: ATTTG
# -> In edge: CTTTG
# Vertex: ATTAG, coverage: 476
# -> Out edge: TTAGG
# -> Out edge: TTAGC
# -> Out edge: TTAGT
# -> Out edge: TTAGA
# -> In edge: AATTA
# -> In edge: TATTA
# -> In edge: GATTA
# -> In edge: CATTA
# Vertex: AGTCT, coverage: 381
# -> Out edge: GTCTC
# -> Out edge: GTCTT
# -> Out edge: GTCTA
# -> Out edge: GTCTG
# -> In edge: TAGTC
# -> In edge: CAGTC
# -> In edge: GAGTC
# -> In edge: AAGTC
# Vertex: TGTAT, coverage: 381
# -> Out edge: GTATA
# -> Out edge: GTATG
# -> Out edge: GTATT
# -> In edge: CTGTA
# -> In edge: ATGTA
# -> In edge: GTGTA
# -> In edge: TTGTA
# Vertex: GGAGG, coverage: 629
# -> Out edge: GAGGT
# -> Out edge: GAGGC
# -> Out edge: GAGGG
# -> Out edge: GAGGA
# -> In edge: TGGAG
# -> In edge: CGGAG
# -> In edge: AGGAG
# -> In edge: GGGAG
# Vertex: GCAAG, coverage: 110
# -> Out edge: CAAGT
# -> Out edge: CAAGG
# -> Out edge: CAAGA
# -> Out edge: CAAGC
# -> In edge: GGCAA
# -> In edge: CGCAA
# -> In edge: TGCAA
# -> In edge: AGCAA
# Vertex: ATTAC, coverage: 15
# -> Out edge: TTACC
# -> Out edge: TTACA
# -> Out edge: TTACT
# -> In edge: GATTA
# -> In edge: TATTA
# -> In edge: AATTA
# -> In edge: CATTA
# Vertex: AGCGG, coverage: 241
# -> Out edge: GCGGA
# -> Out edge: GCGGT
# -> Out edge: GCGGG
# -> Out edge: GCGGC
# -> In edge: TAGCG
# -> In edge: GAGCG
# -> In edge: AAGCG
# -> In edge: CAGCG
# Vertex: CAGTG, coverage: 200
# -> Out edge: AGTGA
# -> Out edge: AGTGC
# -> Out edge: AGTGT
# -> Out edge: AGTGG
# -> In edge: GCAGT
# -> In edge: TCAGT
# -> In edge: CCAGT
# -> In edge: ACAGT
# Vertex: GATGC, coverage: 110
# -> Out edge: ATGCG
# -> Out edge: ATGCC
# -> Out edge: ATGCA
# -> Out edge: ATGCT
# -> In edge: AGATG
# -> In edge: TGATG
# -> In edge: GGATG
# -> In edge: CGATG
# Vertex: TTTCT, coverage: 404
# -> Out edge: TTCTC
# -> Out edge: TTCTT
# -> Out edge: TTCTA
# -> Out edge: TTCTG
# -> In edge: ATTTC
# -> In edge: GTTTC
# -> In edge: TTTTC
# -> In edge: CTTTC
# Vertex: CTTTA, coverage: 380
# -> Out edge: TTTAG
# -> Out edge: TTTAA
# -> Out edge: TTTAT
# -> Out edge: TTTAC
# -> In edge: CCTTT
# -> In edge: TCTTT
# -> In edge: GCTTT
# -> In edge: ACTTT
# Vertex: GCGAA, coverage: 295
# -> Out edge: CGAAT
# -> Out edge: CGAAA
# -> Out edge: CGAAC
# -> Out edge: CGAAG
# -> In edge: TGCGA
# -> In edge: CGCGA
# -> In edge: GGCGA
# -> In edge: AGCGA
# Vertex: ATTGA, coverage: 659
# -> Out edge: TTGAA
# -> Out edge: TTGAT
# -> Out edge: TTGAG
# -> Out edge: TTGAC
# -> In edge: AATTG
# -> In edge: GATTG
# -> In edge: TATTG
# -> In edge: CATTG
# Vertex: ATTTT, coverage: 390
# -> Out edge: TTTTG
# -> Out edge: TTTTA
# -> Out edge: TTTTC
# -> Out edge: TTTTT
# -> In edge: TATTT
# -> In edge: AATTT
# -> In edge: CATTT
# -> In edge: GATTT
# Vertex: GACCC, coverage: 365
# -> Out edge: ACCCC
# -> Out edge: ACCCT
# -> Out edge: ACCCA
# -> Out edge: ACCCG
# -> In edge: GGACC
# -> In edge: TGACC
# -> In edge: AGACC
# -> In edge: CGACC
# Vertex: TGACG, coverage: 98
# -> Out edge: GACGC
# -> Out edge: GACGA
# -> Out edge: GACGG
# -> Out edge: GACGT
# -> In edge: CTGAC
# -> In edge: ATGAC
# -> In edge: GTGAC
# -> In edge: TTGAC
# Vertex: TATGA, coverage: 192
# -> Out edge: ATGAA
# -> Out edge: ATGAC
# -> Out edge: ATGAT
# -> Out edge: ATGAG
# -> In edge: GTATG
# -> In edge: ATATG
# -> In edge: TTATG
# Vertex: ATACA, coverage: 517
# -> Out edge: TACAC
# -> Out edge: TACAT
# -> Out edge: TACAG
# -> Out edge: TACAA
# -> In edge: CATAC
# -> In edge: AATAC
# -> In edge: TATAC
# -> In edge: GATAC
# Vertex: GGCAC, coverage: 372
# -> Out edge: GCACG
# -> Out edge: GCACA
# -> Out edge: GCACC
# -> Out edge: GCACT
# -> In edge: GGGCA
# -> In edge: CGGCA
# -> In edge: TGGCA
# -> In edge: AGGCA
# Vertex: TCACG, coverage: 101
# -> Out edge: CACGA
# -> Out edge: CACGT
# -> Out edge: CACGC
# -> Out edge: CACGG
# -> In edge: ATCAC
# -> In edge: CTCAC
# -> In edge: GTCAC
# -> In edge: TTCAC
# Vertex: GTATG, coverage: 469
# -> Out edge: TATGC
# -> Out edge: TATGA
# -> Out edge: TATGT
# -> Out edge: TATGG
# -> In edge: AGTAT
# -> In edge: TGTAT
# -> In edge: GGTAT
# -> In edge: CGTAT
# Vertex: AATTG, coverage: 384
# -> Out edge: ATTGG
# -> Out edge: ATTGA
# -> Out edge: ATTGC
# -> Out edge: ATTGT
# -> In edge: AAATT
# -> In edge: TAATT
# -> In edge: CAATT
# -> In edge: GAATT
# Vertex: AGTCG, coverage: 10
# -> Out edge: GTCGA
# -> Out edge: GTCGC
# -> Out edge: GTCGT
# -> Out edge: GTCGG
# -> In edge: TAGTC
# -> In edge: CAGTC
# -> In edge: GAGTC
# Vertex: GTAAC, coverage: 461
# -> Out edge: TAACC
# -> Out edge: TAACA
# -> Out edge: TAACT
# -> Out edge: TAACG
# -> In edge: GGTAA
# -> In edge: AGTAA
# -> In edge: CGTAA
# -> In edge: TGTAA
# Vertex: TAGTT, coverage: 285
# -> Out edge: AGTTA
# -> Out edge: AGTTG
# -> Out edge: AGTTT
# -> Out edge: AGTTC
# -> In edge: GTAGT
# -> In edge: CTAGT
# -> In edge: TTAGT
# -> In edge: ATAGT
# Vertex: GTATC, coverage: 97
# -> Out edge: TATCT
# -> Out edge: TATCC
# -> Out edge: TATCA
# -> In edge: GGTAT
# -> In edge: AGTAT
# -> In edge: CGTAT
# Vertex: TTATC, coverage: 191
# -> Out edge: TATCT
# -> Out edge: TATCC
# -> Out edge: TATCG
# -> Out edge: TATCA
# -> In edge: GTTAT
# -> In edge: TTTAT
# -> In edge: ATTAT
# -> In edge: CTTAT
# Vertex: CATGA, coverage: 196
# -> Out edge: ATGAA
# -> Out edge: ATGAG
# -> Out edge: ATGAT
# -> Out edge: ATGAC
# -> In edge: CCATG
# -> In edge: GCATG
# -> In edge: ACATG
# -> In edge: TCATG
# Vertex: GGATG, coverage: 314
# -> Out edge: GATGC
# -> Out edge: GATGG
# -> Out edge: GATGT
# -> Out edge: GATGA
# -> In edge: TGGAT
# -> In edge: CGGAT
# -> In edge: AGGAT
# -> In edge: GGGAT
# Vertex: CACCC, coverage: 386
# -> Out edge: ACCCC
# -> Out edge: ACCCT
# -> Out edge: ACCCA
# -> Out edge: ACCCG
# -> In edge: ACACC
# -> In edge: CCACC
# -> In edge: GCACC
# -> In edge: TCACC
# Vertex: TACGT, coverage: 8
# -> Out edge: ACGTA
# -> Out edge: ACGTC
# -> Out edge: ACGTT
# -> In edge: TTACG
# -> In edge: CTACG
# -> In edge: ATACG
# -> In edge: GTACG
# Vertex: GTCCG, coverage: 465
# -> Out edge: TCCGC
# -> Out edge: TCCGG
# -> Out edge: TCCGA
# -> Out edge: TCCGT
# -> In edge: AGTCC
# -> In edge: TGTCC
# -> In edge: CGTCC
# -> In edge: GGTCC
# Vertex: GAGCC, coverage: 356
# -> Out edge: AGCCG
# -> Out edge: AGCCA
# -> Out edge: AGCCC
# -> Out edge: AGCCT
# -> In edge: GGAGC
# -> In edge: AGAGC
# -> In edge: TGAGC
# -> In edge: CGAGC
# Vertex: TGAGT, coverage: 393
# -> Out edge: GAGTA
# -> Out edge: GAGTC
# -> Out edge: GAGTG
# -> Out edge: GAGTT
# -> In edge: CTGAG
# -> In edge: GTGAG
# -> In edge: TTGAG
# -> In edge: ATGAG
# Vertex: GACGA, coverage: 191
# -> Out edge: ACGAT
# -> Out edge: ACGAA
# -> Out edge: ACGAG
# -> In edge: TGACG
# -> In edge: AGACG
# -> In edge: GGACG
# -> In edge: CGACG
# Vertex: CGATC, coverage: 10
# -> Out edge: GATCC
# -> Out edge: GATCA
# -> Out edge: GATCT
# -> Out edge: GATCG
# -> In edge: GCGAT
# -> In edge: CCGAT
# -> In edge: TCGAT
# Vertex: CGCCA, coverage: 7
# -> Out edge: GCCAG
# -> Out edge: GCCAT
# -> Out edge: GCCAA
# -> Out edge: GCCAC
# -> In edge: GCGCC
# -> In edge: CCGCC
# -> In edge: TCGCC
# -> In edge: ACGCC
# Vertex: TGTAA, coverage: 561
# -> Out edge: GTAAG
# -> Out edge: GTAAC
# -> Out edge: GTAAA
# -> Out edge: GTAAT
# -> In edge: CTGTA
# -> In edge: GTGTA
# -> In edge: ATGTA
# -> In edge: TTGTA
# Vertex: GTTGC, coverage: 373
# -> Out edge: TTGCA
# -> Out edge: TTGCT
# -> Out edge: TTGCC
# -> Out edge: TTGCG
# -> In edge: CGTTG
# -> In edge: AGTTG
# -> In edge: TGTTG
# -> In edge: GGTTG
# Vertex: CTTGG, coverage: 476
# -> Out edge: TTGGA
# -> Out edge: TTGGG
# -> Out edge: TTGGC
# -> Out edge: TTGGT
# -> In edge: TCTTG
# -> In edge: CCTTG
# -> In edge: ACTTG
# -> In edge: GCTTG
# Vertex: AGCTT, coverage: 106
# -> Out edge: GCTTC
# -> Out edge: GCTTG
# -> Out edge: GCTTT
# -> In edge: CAGCT
# -> In edge: TAGCT
# -> In edge: GAGCT
# -> In edge: AAGCT
# Vertex: AATGA, coverage: 394
# -> Out edge: ATGAA
# -> Out edge: ATGAC
# -> Out edge: ATGAT
# -> Out edge: ATGAG
# -> In edge: TAATG
# -> In edge: AAATG
# -> In edge: CAATG
# -> In edge: GAATG
# Vertex: AACTT, coverage: 109
# -> Out edge: ACTTG
# -> Out edge: ACTTC
# -> Out edge: ACTTT
# -> In edge: GAACT
# -> In edge: TAACT
# -> In edge: CAACT
# -> In edge: AAACT
# Vertex: CTGTC, coverage: 14
# -> Out edge: TGTCC
# -> Out edge: TGTCA
# -> Out edge: TGTCG
# -> Out edge: TGTCT
# -> In edge: ACTGT
# -> In edge: CCTGT
# -> In edge: GCTGT
# -> In edge: TCTGT
# Vertex: CTAGA, coverage: 566
# -> Out edge: TAGAG
# -> Out edge: TAGAA
# -> Out edge: TAGAC
# -> Out edge: TAGAT
# -> In edge: TCTAG
# -> In edge: ACTAG
# -> In edge: CCTAG
# -> In edge: GCTAG
# Vertex: TCCGT, coverage: 193
# -> Out edge: CCGTG
# -> Out edge: CCGTC
# -> Out edge: CCGTA
# -> Out edge: CCGTT
# -> In edge: GTCCG
# -> In edge: CTCCG
# -> In edge: TTCCG
# -> In edge: ATCCG
# Vertex: AGCTG, coverage: 190
# -> Out edge: GCTGA
# -> Out edge: GCTGG
# -> Out edge: GCTGC
# -> In edge: CAGCT
# -> In edge: TAGCT
# -> In edge: GAGCT
# -> In edge: AAGCT
# Vertex: ACGGT, coverage: 279
# -> Out edge: CGGTG
# -> Out edge: CGGTC
# -> Out edge: CGGTT
# -> Out edge: CGGTA
# -> In edge: AACGG
# -> In edge: TACGG
# -> In edge: GACGG
# -> In edge: CACGG
# Vertex: AGAGC, coverage: 112
# -> Out edge: GAGCG
# -> Out edge: GAGCT
# -> Out edge: GAGCC
# -> Out edge: GAGCA
# -> In edge: CAGAG
# -> In edge: TAGAG
# -> In edge: AAGAG
# -> In edge: GAGAG
# Vertex: TTAGT, coverage: 196
# -> Out edge: TAGTC
# -> Out edge: TAGTG
# -> Out edge: TAGTA
# -> Out edge: TAGTT
# -> In edge: TTTAG
# -> In edge: GTTAG
# -> In edge: CTTAG
# -> In edge: ATTAG
# Vertex: TGTTC, coverage: 648
# -> Out edge: GTTCA
# -> Out edge: GTTCG
# -> Out edge: GTTCC
# -> Out edge: GTTCT
# -> In edge: ATGTT
# -> In edge: TTGTT
# -> In edge: CTGTT
# -> In edge: GTGTT
# Vertex: CGTAA, coverage: 191
# -> Out edge: GTAAT
# -> Out edge: GTAAA
# -> Out edge: GTAAC
# -> Out edge: GTAAG
# -> In edge: ACGTA
# -> In edge: GCGTA
# -> In edge: CCGTA
# -> In edge: TCGTA
# Vertex: TGTAG, coverage: 185
# -> Out edge: GTAGT
# -> Out edge: GTAGG
# -> Out edge: GTAGA
# -> Out edge: GTAGC
# -> In edge: CTGTA
# -> In edge: GTGTA
# -> In edge: ATGTA
# -> In edge: TTGTA
# Vertex: GGATC, coverage: 500
# -> Out edge: GATCC
# -> Out edge: GATCA
# -> Out edge: GATCT
# -> Out edge: GATCG
# -> In edge: TGGAT
# -> In edge: CGGAT
# -> In edge: AGGAT
# -> In edge: GGGAT
# Vertex: ATCCT, coverage: 287
# -> Out edge: TCCTA
# -> Out edge: TCCTT
# -> Out edge: TCCTG
# -> Out edge: TCCTC
# -> In edge: CATCC
# -> In edge: AATCC
# -> In edge: TATCC
# -> In edge: GATCC
# Vertex: TCGTA, coverage: 104
# -> Out edge: CGTAC
# -> Out edge: CGTAG
# -> Out edge: CGTAA
# -> In edge: CTCGT
# -> In edge: GTCGT
# -> In edge: TTCGT
# -> In edge: ATCGT
# Vertex: TAAAC, coverage: 293
# -> Out edge: AAACC
# -> Out edge: AAACT
# -> Out edge: AAACA
# -> Out edge: AAACG
# -> In edge: TTAAA
# -> In edge: ATAAA
# -> In edge: GTAAA
# -> In edge: CTAAA
# Vertex: GTCCC, coverage: 560
# -> Out edge: TCCCA
# -> Out edge: TCCCC
# -> Out edge: TCCCG
# -> Out edge: TCCCT
# -> In edge: CGTCC
# -> In edge: TGTCC
# -> In edge: AGTCC
# -> In edge: GGTCC
# Vertex: TTTCA, coverage: 11
# -> Out edge: TTCAG
# -> Out edge: TTCAA
# -> Out edge: TTCAT
# -> Out edge: TTCAC
# -> In edge: GTTTC
# -> In edge: TTTTC
# -> In edge: CTTTC
# Vertex: TCCCA, coverage: 565
# -> Out edge: CCCAC
# -> Out edge: CCCAT
# -> Out edge: CCCAG
# -> Out edge: CCCAA
# -> In edge: CTCCC
# -> In edge: ATCCC
# -> In edge: GTCCC
# -> In edge: TTCCC
# Vertex: AGGAC, coverage: 658
# -> Out edge: GGACC
# -> Out edge: GGACA
# -> Out edge: GGACT
# -> Out edge: GGACG
# -> In edge: TAGGA
# -> In edge: AAGGA
# -> In edge: GAGGA
# -> In edge: CAGGA
# Vertex: GAGTA, coverage: 200
# -> Out edge: AGTAC
# -> Out edge: AGTAG
# -> Out edge: AGTAT
# -> Out edge: AGTAA
# -> In edge: AGAGT
# -> In edge: GGAGT
# -> In edge: TGAGT
# -> In edge: CGAGT
# Vertex: TACCT, coverage: 198
# -> Out edge: ACCTG
# -> Out edge: ACCTA
# -> Out edge: ACCTT
# -> In edge: ATACC
# -> In edge: CTACC
# -> In edge: TTACC
# -> In edge: GTACC
# Vertex: CTCGG, coverage: 7
# -> Out edge: TCGGG
# -> Out edge: TCGGA
# -> Out edge: TCGGT
# -> In edge: ACTCG
# -> In edge: GCTCG
# -> In edge: TCTCG
# -> In edge: CCTCG
# Vertex: GAACT, coverage: 178
# -> Out edge: AACTT
# -> Out edge: AACTA
# -> Out edge: AACTG
# -> Out edge: AACTC
# -> In edge: TGAAC
# -> In edge: CGAAC
# -> In edge: GGAAC
# -> In edge: AGAAC
# Vertex: GGGTT, coverage: 281
# -> Out edge: GGTTA
# -> Out edge: GGTTG
# -> Out edge: GGTTT
# -> Out edge: GGTTC
# -> In edge: CGGGT
# -> In edge: TGGGT
# -> In edge: AGGGT
# -> In edge: GGGGT
# Vertex: GCCCT, coverage: 191
# -> Out edge: CCCTA
# -> Out edge: CCCTC
# -> Out edge: CCCTG
# -> Out edge: CCCTT
# -> In edge: TGCCC
# -> In edge: CGCCC
# -> In edge: GGCCC
# -> In edge: AGCCC
# Vertex: GATTG, coverage: 714
# -> Out edge: ATTGA
# -> Out edge: ATTGG
# -> Out edge: ATTGC
# -> Out edge: ATTGT
# -> In edge: TGATT
# -> In edge: AGATT
# -> In edge: GGATT
# -> In edge: CGATT
# Vertex: TTTAT, coverage: 199
# -> Out edge: TTATT
# -> Out edge: TTATA
# -> Out edge: TTATG
# -> Out edge: TTATC
# -> In edge: GTTTA
# -> In edge: CTTTA
# -> In edge: ATTTA
# -> In edge: TTTTA
# Vertex: TTTTC, coverage: 377
# -> Out edge: TTTCG
# -> Out edge: TTTCT
# -> Out edge: TTTCA
# -> Out edge: TTTCC
# -> In edge: GTTTT
# -> In edge: CTTTT
# -> In edge: ATTTT
# -> In edge: TTTTT
# Vertex: TGCGG, coverage: 386
# -> Out edge: GCGGA
# -> Out edge: GCGGT
# -> Out edge: GCGGG
# -> Out edge: GCGGC
# -> In edge: ATGCG
# -> In edge: CTGCG
# -> In edge: GTGCG
# -> In edge: TTGCG
# Vertex: TAATG, coverage: 285
# -> Out edge: AATGT
# -> Out edge: AATGG
# -> Out edge: AATGA
# -> In edge: ATAAT
# -> In edge: GTAAT
# -> In edge: CTAAT
# -> In edge: TTAAT
# Vertex: CCGCT, coverage: 10
# -> Out edge: CGCTC
# -> Out edge: CGCTA
# -> Out edge: CGCTT
# -> Out edge: CGCTG
# -> In edge: ACCGC
# -> In edge: TCCGC
# -> In edge: CCCGC
# Vertex: GATAC, coverage: 190
# -> Out edge: ATACC
# -> Out edge: ATACA
# -> Out edge: ATACG
# -> Out edge: ATACT
# -> In edge: GGATA
# -> In edge: CGATA
# -> In edge: TGATA
# -> In edge: AGATA
# Vertex: CGGGA, coverage: 289
# -> Out edge: GGGAG
# -> Out edge: GGGAA
# -> Out edge: GGGAC
# -> Out edge: GGGAT
# -> In edge: TCGGG
# -> In edge: CCGGG
# -> In edge: ACGGG
# -> In edge: GCGGG
# Vertex: ATTTC, coverage: 103
# -> Out edge: TTTCG
# -> Out edge: TTTCT
# -> Out edge: TTTCC
# -> In edge: TATTT
# -> In edge: AATTT
# -> In edge: GATTT
# Vertex: GCTGG, coverage: 660
# -> Out edge: CTGGC
# -> Out edge: CTGGA
# -> Out edge: CTGGT
# -> Out edge: CTGGG
# -> In edge: GGCTG
# -> In edge: AGCTG
# -> In edge: TGCTG
# -> In edge: CGCTG
# Vertex: CTACC, coverage: 98
# -> Out edge: TACCC
# -> Out edge: TACCA
# -> Out edge: TACCT
# -> In edge: CCTAC
# -> In edge: TCTAC
# -> In edge: GCTAC
# Vertex: TTGCG, coverage: 284
# -> Out edge: TGCGC
# -> Out edge: TGCGA
# -> Out edge: TGCGT
# -> Out edge: TGCGG
# -> In edge: GTTGC
# -> In edge: ATTGC
# -> In edge: TTTGC
# -> In edge: CTTGC
# Vertex: ATTTA, coverage: 193
# -> Out edge: TTTAG
# -> Out edge: TTTAA
# -> Out edge: TTTAT
# -> Out edge: TTTAC
# -> In edge: TATTT
# -> In edge: AATTT
# -> In edge: CATTT
# -> In edge: GATTT
# Vertex: ATGGT, coverage: 569
# -> Out edge: TGGTC
# -> Out edge: TGGTG
# -> Out edge: TGGTA
# -> Out edge: TGGTT
# -> In edge: CATGG
# -> In edge: GATGG
# -> In edge: AATGG
# -> In edge: TATGG
# Vertex: TTCCC, coverage: 569
# -> Out edge: TCCCA
# -> Out edge: TCCCC
# -> Out edge: TCCCG
# -> Out edge: TCCCT
# -> In edge: TTTCC
# -> In edge: ATTCC
# -> In edge: GTTCC
# -> In edge: CTTCC
# Vertex: GATTT, coverage: 293
# -> Out edge: ATTTA
# -> Out edge: ATTTC
# -> Out edge: ATTTT
# -> Out edge: ATTTG
# -> In edge: TGATT
# -> In edge: AGATT
# -> In edge: GGATT
# -> In edge: CGATT
# Vertex: ACAGG, coverage: 425
# -> Out edge: CAGGC
# -> Out edge: CAGGT
# -> Out edge: CAGGG
# -> Out edge: CAGGA
# -> In edge: AACAG
# -> In edge: CACAG
# -> In edge: TACAG
# -> In edge: GACAG
# Vertex: TAGTG, coverage: 198
# -> Out edge: AGTGA
# -> Out edge: AGTGC
# -> Out edge: AGTGT
# -> Out edge: AGTGG
# -> In edge: GTAGT
# -> In edge: CTAGT
# -> In edge: TTAGT
# -> In edge: ATAGT
# Vertex: CAGGA, coverage: 911
# -> Out edge: AGGAC
# -> Out edge: AGGAG
# -> Out edge: AGGAT
# -> Out edge: AGGAA
# -> In edge: ACAGG
# -> In edge: TCAGG
# -> In edge: CCAGG
# -> In edge: GCAGG
# Vertex: ACAGA, coverage: 566
# -> Out edge: CAGAG
# -> Out edge: CAGAT
# -> Out edge: CAGAC
# -> Out edge: CAGAA
# -> In edge: TACAG
# -> In edge: AACAG
# -> In edge: CACAG
# -> In edge: GACAG
# Vertex: AGATC, coverage: 296
# -> Out edge: GATCC
# -> Out edge: GATCA
# -> Out edge: GATCT
# -> Out edge: GATCG
# -> In edge: GAGAT
# -> In edge: CAGAT
# -> In edge: AAGAT
# -> In edge: TAGAT
# Vertex: CACGA, coverage: 202
# -> Out edge: ACGAG
# -> Out edge: ACGAC
# -> Out edge: ACGAA
# -> Out edge: ACGAT
# -> In edge: ACACG
# -> In edge: CCACG
# -> In edge: GCACG
# -> In edge: TCACG
# Vertex: GGCTG, coverage: 246
# -> Out edge: GCTGA
# -> Out edge: GCTGG
# -> Out edge: GCTGT
# -> Out edge: GCTGC
# -> In edge: AGGCT
# -> In edge: GGGCT
# -> In edge: CGGCT
# -> In edge: TGGCT
# Vertex: CCGGT, coverage: 11
# -> Out edge: CGGTG
# -> Out edge: CGGTT
# -> Out edge: CGGTA
# -> In edge: TCCGG
# -> In edge: ACCGG
# -> In edge: CCCGG
# -> In edge: GCCGG
# Vertex: CGAGT, coverage: 109
# -> Out edge: GAGTA
# -> Out edge: GAGTC
# -> Out edge: GAGTG
# -> Out edge: GAGTT
# -> In edge: ACGAG
# -> In edge: GCGAG
# -> In edge: CCGAG
# -> In edge: TCGAG
# Vertex: GTTGT, coverage: 205
# -> Out edge: TTGTC
# -> Out edge: TTGTG
# -> Out edge: TTGTT
# -> Out edge: TTGTA
# -> In edge: CGTTG
# -> In edge: AGTTG
# -> In edge: TGTTG
# -> In edge: GGTTG
# Vertex: ACTTT, coverage: 204
# -> Out edge: CTTTT
# -> Out edge: CTTTA
# -> Out edge: CTTTC
# -> Out edge: CTTTG
# -> In edge: CACTT
# -> In edge: AACTT
# -> In edge: GACTT
# -> In edge: TACTT
# Vertex: AGCGT, coverage: 8
# -> Out edge: GCGTG
# -> Out edge: GCGTC
# -> Out edge: GCGTT
# -> In edge: GAGCG
# -> In edge: TAGCG
# -> In edge: AAGCG
# Vertex: GTGCA, coverage: 374
# -> Out edge: TGCAG
# -> Out edge: TGCAA
# -> Out edge: TGCAC
# -> In edge: CGTGC
# -> In edge: AGTGC
# -> In edge: TGTGC
# -> In edge: GGTGC
# Vertex: CTTAC, coverage: 6
# -> Out edge: TTACG
# -> Out edge: TTACA
# -> Out edge: TTACT
# -> In edge: CCTTA
# -> In edge: TCTTA
# -> In edge: GCTTA
# Vertex: AATTT, coverage: 479
# -> Out edge: ATTTC
# -> Out edge: ATTTT
# -> Out edge: ATTTG
# -> Out edge: ATTTA
# -> In edge: AAATT
# -> In edge: TAATT
# -> In edge: CAATT
# -> In edge: GAATT
# Vertex: AAGGC, coverage: 754
# -> Out edge: AGGCT
# -> Out edge: AGGCC
# -> Out edge: AGGCG
# -> Out edge: AGGCA
# -> In edge: TAAGG
# -> In edge: AAAGG
# -> In edge: CAAGG
# -> In edge: GAAGG
# Vertex: TCGCC, coverage: 9
# -> Out edge: CGCCC
# -> Out edge: CGCCA
# -> Out edge: CGCCT
# -> Out edge: CGCCG
# -> In edge: GTCGC
# -> In edge: CTCGC
# -> In edge: TTCGC
# Vertex: GAGAT, coverage: 391
# -> Out edge: AGATG
# -> Out edge: AGATT
# -> Out edge: AGATC
# -> Out edge: AGATA
# -> In edge: TGAGA
# -> In edge: CGAGA
# -> In edge: AGAGA
# -> In edge: GGAGA
# Vertex: GGCTT, coverage: 195
# -> Out edge: GCTTG
# -> Out edge: GCTTC
# -> Out edge: GCTTT
# -> Out edge: GCTTA
# -> In edge: AGGCT
# -> In edge: GGGCT
# -> In edge: TGGCT
# -> In edge: CGGCT
# Vertex: GGATT, coverage: 640
# -> Out edge: GATTA
# -> Out edge: GATTG
# -> Out edge: GATTT
# -> Out edge: GATTC
# -> In edge: TGGAT
# -> In edge: CGGAT
# -> In edge: AGGAT
# -> In edge: GGGAT
# ...
# 	GTGGT [label="coverage=371"]
# 	GTGGT -> TGGTC [label="len=6,cov=417.5"]
# 	GTGGT -> TGGTG [label="len=6,cov=744.0"]
# 	GTGGT -> TGGTA [label="len=6,cov=376.5"]
# 	GTGGT -> TGGTT [label="len=6,cov=239.0"]
# 	TTCAA [label="coverage=21"]
# 	TTCAA -> TCAAT [label="len=6,cov=105.0"]
# 	TTCAA -> TCAAG [label="len=6,cov=109.5"]
# 	TTCAA -> TCAAA [label="len=6,cov=34.5"]
# 	TTCAA -> TCAAC [label="len=6,cov=108.0"]
# 	TATCT [label="coverage=102"]
# 	TATCT -> ATCTT [label="len=6,cov=257.0"]
# 	TATCT -> ATCTG [label="len=6,cov=103.5"]
# 	TATCT -> ATCTA [label="len=6,cov=101.5"]
# 	TATCT -> ATCTC [label="len=6,cov=193.5"]
# 	TTCGG [label="coverage=9"]
# 	TTCGG -> TCGGG [label="len=6,cov=55.0"]
# 	TTCGG -> TCGGT [label="len=6,cov=97.5"]
# 	TTCGG -> TCGGC [label="len=6,cov=55.0"]
# 	GGCGG [label="coverage=184"]
# 	GGCGG -> GCGGA [label="len=6,cov=144.0"]
# 	GGCGG -> GCGGT [label="len=6,cov=323.5"]
# 	GGCGG -> GCGGG [label="len=6,cov=168.0"]
# 	GGCGG -> GCGGC [label="len=6,cov=189.0"]
# 	GCAAT [label="coverage=288"]
# 	GCAAT -> CAATG [label="len=6,cov=336.0"]
# 	GCAAT -> CAATT [label="len=6,cov=332.5"]
# 	GCAAT -> CAATC [label="len=6,cov=331.0"]
# 	GCAAT -> CAATA [label="len=6,cov=290.0"]
# 	TGGTC [label="coverage=464"]
# 	TGGTC -> GGTCT [label="len=6,cov=377.5"]
# 	TGGTC -> GGTCG [label="len=6,cov=548.0"]
# 	TGGTC -> GGTCA [label="len=6,cov=240.0"]
# 	TGGTC -> GGTCC [label="len=6,cov=465.0"]
# 	TAGCG [label="coverage=7"]
# 	TAGCG -> AGCGG [label="len=6,cov=124.0"]
# 	TAGCG -> AGCGC [label="len=6,cov=97.5"]
# 	TAGCG -> AGCGT [label="len=6,cov=7.5"]
# 	TAGCG -> AGCGA [label="len=6,cov=143.5"]
# 	AAAGT [label="coverage=486"]
# 	AAAGT -> AAGTC [label="len=6,cov=388.0"]
# 	AAAGT -> AAGTA [label="len=6,cov=341.5"]
# 	AAAGT -> AAGTT [label="len=6,cov=524.0"]
# 	AAAGT -> AAGTG [label="len=6,cov=438.0"]
# 	GCCAA [label="coverage=202"]
# 	GCCAA -> CCAAG [label="len=6,cov=427.0"]
# 	GCCAA -> CCAAC [label="len=6,cov=244.5"]
# 	GCCAA -> CCAAA [label="len=6,cov=526.0"]
# 	GCCAA -> CCAAT [label="len=6,cov=471.5"]
# 	AACGA [label="coverage=199"]
# 	AACGA -> ACGAT [label="len=6,cov=194.5"]
# 	AACGA -> ACGAC [label="len=6,cov=104.5"]
# 	AACGA -> ACGAG [label="len=6,cov=290.0"]
# 	AACGA -> ACGAA [label="len=6,cov=156.5"]
# 	TCCGC [label="coverage=286"]
# 	TCCGC -> CCGCA [label="len=6,cov=291.0"]
# 	TCCGC -> CCGCG [label="len=6,cov=236.0"]
# 	TCCGC -> CCGCT [label="len=6,cov=148.0"]
# 	TCCGC -> CCGCC [label="len=6,cov=237.5"]
# 	CATGT [label="coverage=101"]
# 	CATGT -> ATGTA [label="len=6,cov=234.5"]
# 	CATGT -> ATGTT [label="len=6,cov=247.0"]
# 	CATGT -> ATGTG [label="len=6,cov=240.0"]
# 	CATGT -> ATGTC [label="len=6,cov=144.0"]
# 	GAAGT [label="coverage=749"]
# 	GAAGT -> AAGTC [label="len=6,cov=519.5"]
# 	GAAGT -> AAGTA [label="len=6,cov=473.0"]
# 	GAAGT -> AAGTT [label="len=6,cov=655.5"]
# 	GAAGT -> AAGTG [label="len=6,cov=569.5"]
# 	CGCGT [label="coverage=94"]
# 	CGCGT -> GCGTA [label="len=6,cov=95.0"]
# 	CGCGT -> GCGTC [label="len=6,cov=146.0"]
# 	CGCGT -> GCGTT [label="len=6,cov=98.5"]
# 	ATGTT [label="coverage=393"]
# 	ATGTT -> TGTTT [label="len=6,cov=540.0"]
# 	ATGTT -> TGTTA [label="len=6,cov=293.5"]
# 	ATGTT -> TGTTG [label="len=6,cov=483.5"]
# 	ATGTT -> TGTTC [label="len=6,cov=520.5"]
# 	ATGTG [label="coverage=379"]
# 	ATGTG -> TGTGT [label="len=6,cov=382.0"]
# 	ATGTG -> TGTGC [label="len=6,cov=193.5"]
# 	ATGTG -> TGTGA [label="len=6,cov=380.5"]
# 	ATGTG -> TGTGG [label="len=6,cov=242.0"]
# 	AGGTA [label="coverage=301"]
# 	AGGTA -> GGTAA [label="len=6,cov=381.0"]
# 	AGGTA -> GGTAT [label="len=6,cov=295.0"]
# 	AGGTA -> GGTAG [label="len=6,cov=276.0"]
# 	AGGTA -> GGTAC [label="len=6,cov=254.5"]
# 	ATACT [label="coverage=288"]
# 	ATACT -> TACTG [label="len=6,cov=232.5"]
# 	ATACT -> TACTC [label="len=6,cov=195.5"]
# 	ATACT -> TACTA [label="len=6,cov=236.0"]
# 	ATACT -> TACTT [label="len=6,cov=195.0"]
# 	CGCCT [label="coverage=190"]
# 	CGCCT -> GCCTG [label="len=6,cov=378.0"]
# 	CGCCT -> GCCTT [label="len=6,cov=218.0"]
# 	CGCCT -> GCCTA [label="len=6,cov=241.0"]
# 	CGCCT -> GCCTC [label="len=6,cov=305.0"]
# 	GCCTC [label="coverage=420"]
# 	GCCTC -> CCTCG [label="len=6,cov=308.0"]
# 	GCCTC -> CCTCC [label="len=6,cov=399.5"]
# 	GCCTC -> CCTCA [label="len=6,cov=261.5"]
# 	GCCTC -> CCTCT [label="len=6,cov=282.5"]
# 	CTCAT [label="coverage=97"]
# 	CTCAT -> TCATT [label="len=6,cov=145.0"]
# 	CTCAT -> TCATC [label="len=6,cov=96.0"]
# 	CTCAT -> TCATA [label="len=6,cov=54.5"]
# 	TAGAG [label="coverage=471"]
# 	TAGAG -> AGAGT [label="len=6,cov=660.0"]
# 	TAGAG -> AGAGC [label="len=6,cov=291.5"]
# 	TAGAG -> AGAGG [label="len=6,cov=708.0"]
# 	TAGAG -> AGAGA [label="len=6,cov=481.5"]
# 	CCGCG [label="coverage=186"]
# 	CCGCG -> CGCGA [label="len=6,cov=99.0"]
# 	CCGCG -> CGCGC [label="len=6,cov=140.0"]
# 	CCGCG -> CGCGT [label="len=6,cov=140.0"]
# 	CCGCG -> CGCGG [label="len=6,cov=145.0"]
# 	CAAGA [label="coverage=934"]
# 	CAAGA -> AAGAA [label="len=6,cov=931.5"]
# 	CAAGA -> AAGAT [label="len=6,cov=797.5"]
# 	CAAGA -> AAGAC [label="len=6,cov=790.0"]
# 	CAAGA -> AAGAG [label="len=6,cov=760.5"]
# 	GCCGA [label="coverage=199"]
# 	GCCGA -> CCGAA [label="len=6,cov=340.5"]
# 	GCCGA -> CCGAT [label="len=6,cov=193.5"]
# 	GCCGA -> CCGAC [label="len=6,cov=151.5"]
# 	GCCGA -> CCGAG [label="len=6,cov=205.5"]
# 	TATGT [label="coverage=195"]
# 	TATGT -> ATGTA [label="len=6,cov=281.5"]
# 	TATGT -> ATGTT [label="len=6,cov=294.0"]
# 	TATGT -> ATGTG [label="len=6,cov=287.0"]
# 	TATGT -> ATGTC [label="len=6,cov=191.0"]
# 	CCTTT [label="coverage=189"]
# 	CCTTT -> CTTTA [label="len=6,cov=284.5"]
# 	CCTTT -> CTTTC [label="len=6,cov=150.0"]
# 	CCTTT -> CTTTG [label="len=6,cov=281.5"]
# 	GTTAT [label="coverage=101"]
# 	GTTAT -> TTATA [label="len=6,cov=147.5"]
# 	GTTAT -> TTATT [label="len=6,cov=59.0"]
# 	GTTAT -> TTATG [label="len=6,cov=193.0"]
# 	GTTAT -> TTATC [label="len=6,cov=146.0"]
# 	GGGAA [label="coverage=363"]
# 	GGGAA -> GGAAC [label="len=6,cov=233.5"]
# 	GGGAA -> GGAAA [label="len=6,cov=494.0"]
# 	GGGAA -> GGAAG [label="len=6,cov=387.5"]
# 	GGGAA -> GGAAT [label="len=6,cov=422.0"]
# 	TCGTG [label="coverage=7"]
# 	TCGTG -> CGTGC [label="len=6,cov=146.0"]
# 	TCGTG -> CGTGG [label="len=6,cov=54.0"]
# 	TCGTG -> CGTGT [label="len=6,cov=8.5"]
# 	AATTA [label="coverage=196"]
# 	AATTA -> ATTAA [label="len=6,cov=285.0"]
# 	AATTA -> ATTAC [label="len=6,cov=105.5"]
# 	AATTA -> ATTAT [label="len=6,cov=102.5"]
# 	AATTA -> ATTAG [label="len=6,cov=336.0"]
# 	CAATA [label="coverage=292"]
# 	CAATA -> AATAT [label="len=6,cov=334.5"]
# 	CAATA -> AATAG [label="len=6,cov=293.0"]
# 	CAATA -> AATAC [label="len=6,cov=448.5"]
# 	CAATA -> AATAA [label="len=6,cov=254.5"]
# 	ACAAG [label="coverage=754"]
# 	ACAAG -> CAAGT [label="len=6,cov=430.0"]
# 	ACAAG -> CAAGG [label="len=6,cov=573.5"]
# 	ACAAG -> CAAGA [label="len=6,cov=844.0"]
# 	ACAAG -> CAAGC [label="len=6,cov=518.0"]
# 	CCGCA [label="coverage=296"]
# 	CCGCA -> CGCAG [label="len=6,cov=477.5"]
# 	CCGCA -> CGCAT [label="len=6,cov=199.0"]
# 	CCGCA -> CGCAA [label="len=6,cov=156.0"]
# 	CCGCA -> CGCAC [label="len=6,cov=152.5"]
# 	AATCC [label="coverage=377"]
# 	AATCC -> ATCCC [label="len=6,cov=241.5"]
# 	AATCC -> ATCCG [label="len=6,cov=194.0"]
# 	AATCC -> ATCCT [label="len=6,cov=332.0"]
# 	AATCC -> ATCCA [label="len=6,cov=514.5"]
# 	TACTT [label="coverage=102"]
# 	TACTT -> ACTTA [label="len=6,cov=53.0"]
# 	TACTT -> ACTTG [label="len=6,cov=149.0"]
# 	TACTT -> ACTTC [label="len=6,cov=58.5"]
# 	TACTT -> ACTTT [label="len=6,cov=153.0"]
# 	CTAAA [label="coverage=106"]
# 	CTAAA -> TAAAT [label="len=6,cov=238.0"]
# 	CTAAA -> TAAAA [label="len=6,cov=337.0"]
# 	CTAAA -> TAAAC [label="len=6,cov=199.5"]
# 	CTAAA -> TAAAG [label="len=6,cov=294.0"]
# 	CTCGT [label="coverage=192"]
# 	CTCGT -> TCGTG [label="len=6,cov=99.5"]
# 	CTCGT -> TCGTC [label="len=6,cov=283.5"]
# 	CTCGT -> TCGTA [label="len=6,cov=148.0"]
# 	CTCGA [label="coverage=106"]
# 	CTCGA -> TCGAA [label="len=6,cov=60.0"]
# 	CTCGA -> TCGAG [label="len=6,cov=105.0"]
# 	CTCGA -> TCGAT [label="len=6,cov=106.0"]
# 	CTCGA -> TCGAC [label="len=6,cov=55.0"]
# 	CTTAA [label="coverage=11"]
# 	CTTAA -> TTAAC [label="len=6,cov=195.5"]
# 	CTTAA -> TTAAG [label="len=6,cov=11.0"]
# 	CTTAA -> TTAAA [label="len=6,cov=147.0"]
# 	CTTAA -> TTAAT [label="len=6,cov=108.0"]
# 	TCTGA [label="coverage=108"]
# 	TCTGA -> CTGAA [label="len=6,cov=324.0"]
# 	TCTGA -> CTGAG [label="len=6,cov=385.5"]
# 	TCTGA -> CTGAT [label="len=6,cov=153.0"]
# 	TCTGA -> CTGAC [label="len=6,cov=138.0"]
# 	ATCGG [label="coverage=100"]
# 	ATCGG -> TCGGA [label="len=6,cov=96.0"]
# 	ATCGG -> TCGGG [label="len=6,cov=100.5"]
# 	ATCGG -> TCGGT [label="len=6,cov=143.0"]
# 	ATCGG -> TCGGC [label="len=6,cov=100.5"]
# 	TGGAC [label="coverage=11"]
# 	TGGAC -> GGACT [label="len=6,cov=103.0"]
# 	TGGAC -> GGACA [label="len=6,cov=243.0"]
# 	TGGAC -> GGACG [label="len=6,cov=148.0"]
# 	TGGGC [label="coverage=286"]
# 	TGGGC -> GGGCG [label="len=6,cov=196.5"]
# 	TGGGC -> GGGCC [label="len=6,cov=198.0"]
# 	TGGGC -> GGGCT [label="len=6,cov=239.0"]
# 	TGGGC -> GGGCA [label="len=6,cov=378.0"]
# 	CAAAA [label="coverage=750"]
# 	CAAAA -> AAAAC [label="len=6,cov=706.5"]
# 	CAAAA -> AAAAT [label="len=6,cov=569.0"]
# 	CAAAA -> AAAAG [label="len=6,cov=801.5"]
# 	CAAAA -> AAAAA [label="len=6,cov=575.5"]
# 	TTGGA [label="coverage=466"]
# 	TTGGA -> TGGAG [label="len=6,cov=512.5"]
# 	TTGGA -> TGGAT [label="len=6,cov=517.5"]
# 	TTGGA -> TGGAA [label="len=6,cov=433.0"]
# 	CGACG [label="coverage=272"]
# 	CGACG -> GACGC [label="len=6,cov=232.0"]
# 	CGACG -> GACGA [label="len=6,cov=231.5"]
# 	CGACG -> GACGG [label="len=6,cov=277.5"]
# 	CGACG -> GACGT [label="len=6,cov=278.5"]
# 	CTATG [label="coverage=99"]
# 	CTATG -> TATGC [label="len=6,cov=193.5"]
# 	CTATG -> TATGG [label="len=6,cov=193.0"]
# 	CTATG -> TATGT [label="len=6,cov=147.0"]
# 	CCATC [label="coverage=105"]
# 	CCATC -> CATCA [label="len=6,cov=151.5"]
# 	CCATC -> CATCC [label="len=6,cov=196.5"]
# 	CCATC -> CATCT [label="len=6,cov=99.5"]
# 	CCATC -> CATCG [label="len=6,cov=57.5"]
# 	CCAAC [label="coverage=287"]
# 	CCAAC -> CAACC [label="len=6,cov=153.0"]
# 	CCAAC -> CAACG [label="len=6,cov=241.5"]
# 	CCAAC -> CAACT [label="len=6,cov=238.5"]
# 	CCAAC -> CAACA [label="len=6,cov=425.5"]
# 	GCTAG [label="coverage=198"]
# 	GCTAG -> CTAGT [label="len=6,cov=239.5"]
# 	GCTAG -> CTAGG [label="len=6,cov=286.0"]
# 	GCTAG -> CTAGC [label="len=6,cov=150.0"]
# 	GCTAG -> CTAGA [label="len=6,cov=382.0"]
# 	GGCAT [label="coverage=468"]
# 	GGCAT -> GCATA [label="len=6,cov=378.0"]
# 	GGCAT -> GCATC [label="len=6,cov=287.5"]
# 	GGCAT -> GCATT [label="len=6,cov=288.0"]
# 	GGCAT -> GCATG [label="len=6,cov=378.5"]
# 	AGCGA [label="coverage=280"]
# 	AGCGA -> GCGAT [label="len=6,cov=272.5"]
# 	AGCGA -> GCGAG [label="len=6,cov=327.5"]
# 	AGCGA -> GCGAA [label="len=6,cov=287.5"]
# 	AGCGA -> GCGAC [label="len=6,cov=277.0"]
# 	TCAGT [label="coverage=110"]
# 	TCAGT -> CAGTA [label="len=6,cov=480.0"]
# 	TCAGT -> CAGTC [label="len=6,cov=198.0"]
# 	TCAGT -> CAGTG [label="len=6,cov=155.0"]
# 	TCAGT -> CAGTT [label="len=6,cov=108.5"]
# 	GTAAG [label="coverage=191"]
# 	GTAAG -> TAAGG [label="len=6,cov=287.0"]
# 	GTAAG -> TAAGT [label="len=6,cov=144.5"]
# 	GTAAG -> TAAGC [label="len=6,cov=146.0"]
# 	GTAAG -> TAAGA [label="len=6,cov=152.5"]
# 	TCGAC [label="coverage=4"]
# 	TCGAC -> CGACA [label="len=6,cov=14.0"]
# 	TCGAC -> CGACG [label="len=6,cov=138.0"]
# 	GTTTG [label="coverage=489"]
# 	GTTTG -> TTTGT [label="len=6,cov=436.0"]
# 	GTTTG -> TTTGA [label="len=6,cov=386.5"]
# 	GTTTG -> TTTGC [label="len=6,cov=480.0"]
# 	GTTTG -> TTTGG [label="len=6,cov=579.0"]
# 	ACCTT [label="coverage=659"]
# 	ACCTT -> CCTTA [label="len=6,cov=428.0"]
# 	ACCTT -> CCTTT [label="len=6,cov=424.0"]
# 	ACCTT -> CCTTG [label="len=6,cov=610.0"]
# 	ACCTT -> CCTTC [label="len=6,cov=453.5"]
# 	CTTCC [label="coverage=432"]
# 	CTTCC -> TTCCT [label="len=6,cov=336.5"]
# 	CTTCC -> TTCCA [label="len=6,cov=496.5"]
# 	CTTCC -> TTCCC [label="len=6,cov=500.5"]
# 	CTTCC -> TTCCG [label="len=6,cov=367.0"]
# 	CGCAC [label="coverage=9"]
# 	CGCAC -> GCACG [label="len=6,cov=8.0"]
# 	CGCAC -> GCACA [label="len=6,cov=241.0"]
# 	CGCAC -> GCACT [label="len=6,cov=52.0"]
# 	CGAGG [label="coverage=208"]
# 	CGAGG -> GAGGT [label="len=6,cov=439.0"]
# 	CGAGG -> GAGGC [label="len=6,cov=513.0"]
# 	CGAGG -> GAGGA [label="len=6,cov=531.0"]
# 	CGAGG -> GAGGG [label="len=6,cov=256.5"]
# 	AAGCG [label="coverage=284"]
# 	AAGCG -> AGCGG [label="len=6,cov=262.5"]
# 	AAGCG -> AGCGC [label="len=6,cov=236.0"]
# 	AAGCG -> AGCGT [label="len=6,cov=146.0"]
# 	AAGCG -> AGCGA [label="len=6,cov=282.0"]
# 	AGTAA [label="coverage=466"]
# 	AGTAA -> GTAAT [label="len=6,cov=282.5"]
# 	AGTAA -> GTAAA [label="len=6,cov=697.5"]
# 	AGTAA -> GTAAC [label="len=6,cov=463.5"]
# 	AGTAA -> GTAAG [label="len=6,cov=328.5"]
# 	GGGGC [label="coverage=204"]
# 	GGGGC -> GGGCG [label="len=6,cov=155.5"]
# 	GGGGC -> GGGCC [label="len=6,cov=157.0"]
# 	GGGGC -> GGGCT [label="len=6,cov=198.0"]
# 	GGGGC -> GGGCA [label="len=6,cov=337.0"]
# 	TCGTT [label="coverage=191"]
# 	TCGTT -> CGTTG [label="len=6,cov=237.0"]
# 	TCGTT -> CGTTT [label="len=6,cov=99.0"]
# 	TCGTT -> CGTTA [label="len=6,cov=99.5"]
# 	TCGTT -> CGTTC [label="len=6,cov=148.0"]
# 	TTAGA [label="coverage=284"]
# 	TTAGA -> TAGAG [label="len=6,cov=377.5"]
# 	TTAGA -> TAGAA [label="len=6,cov=286.5"]
# 	TTAGA -> TAGAC [label="len=6,cov=246.5"]
# 	TTAGA -> TAGAT [label="len=6,cov=284.0"]
# 	TATGC [label="coverage=288"]
# 	TATGC -> ATGCG [label="len=6,cov=245.0"]
# 	TATGC -> ATGCC [label="len=6,cov=331.5"]
# 	TATGC -> ATGCA [label="len=6,cov=240.5"]
# 	TATGC -> ATGCT [label="len=6,cov=330.5"]
# 	CCTCC [label="coverage=379"]
# 	CCTCC -> CTCCC [label="len=6,cov=334.5"]
# 	CCTCC -> CTCCA [label="len=6,cov=513.0"]
# 	CCTCC -> CTCCG [label="len=6,cov=330.5"]
# 	CCTCC -> CTCCT [label="len=6,cov=376.5"]
# 	GAGCA [label="coverage=209"]
# 	GAGCA -> AGCAG [label="len=6,cov=324.0"]
# 	GAGCA -> AGCAA [label="len=6,cov=343.0"]
# 	GAGCA -> AGCAT [label="len=6,cov=116.5"]
# 	GAGCA -> AGCAC [label="len=6,cov=158.0"]
# 	AGAAC [label="coverage=199"]
# 	AGAAC -> GAACT [label="len=6,cov=188.5"]
# 	AGAAC -> GAACC [label="len=6,cov=198.5"]
# 	AGAAC -> GAACG [label="len=6,cov=148.0"]
# 	AGAAC -> GAACA [label="len=6,cov=331.5"]
# 	GGGTG [label="coverage=112"]
# 	GGGTG -> GGTGT [label="len=6,cov=246.0"]
# 	GGGTG -> GGTGA [label="len=6,cov=386.0"]
# 	GGGTG -> GGTGC [label="len=6,cov=254.0"]
# 	GGGTG -> GGTGG [label="len=6,cov=395.0"]
# 	CCTAC [label="coverage=377"]
# 	CCTAC -> CTACA [label="len=6,cov=287.0"]
# 	CCTAC -> CTACG [label="len=6,cov=242.0"]
# 	CCTAC -> CTACC [label="len=6,cov=237.5"]
# 	CCTAC -> CTACT [label="len=6,cov=235.0"]
# 	AGTTA [label="coverage=103"]
# 	AGTTA -> GTTAT [label="len=6,cov=102.0"]
# 	AGTTA -> GTTAG [label="len=6,cov=102.0"]
# 	AGTTA -> GTTAC [label="len=6,cov=55.5"]
# 	GACGC [label="coverage=192"]
# 	GACGC -> ACGCT [label="len=6,cov=145.5"]
# 	GACGC -> ACGCA [label="len=6,cov=194.5"]
# 	GACGC -> ACGCG [label="len=6,cov=146.5"]
# 	GACGC -> ACGCC [label="len=6,cov=149.0"]
# 	TGATG [label="coverage=487"]
# 	TGATG -> GATGC [label="len=6,cov=298.5"]
# 	TGATG -> GATGG [label="len=6,cov=441.0"]
# 	TGATG -> GATGA [label="len=6,cov=541.5"]
# 	TGATG -> GATGT [label="len=6,cov=525.0"]
# 	CGACT [label="coverage=7"]
# 	CGACT -> GACTC [label="len=6,cov=147.0"]
# 	CGACT -> GACTG [label="len=6,cov=89.0"]
# 	CGACT -> GACTT [label="len=6,cov=57.5"]
# 	CCAGT [label="coverage=368"]
# 	CCAGT -> CAGTA [label="len=6,cov=609.0"]
# 	CCAGT -> CAGTC [label="len=6,cov=327.0"]
# 	CCAGT -> CAGTG [label="len=6,cov=284.0"]
# 	CCAGT -> CAGTT [label="len=6,cov=237.5"]
# 	TAGGT [label="coverage=104"]
# 	TAGGT -> AGGTG [label="len=6,cov=352.0"]
# 	TAGGT -> AGGTA [label="len=6,cov=202.5"]
# 	TAGGT -> AGGTC [label="len=6,cov=200.0"]
# 	TAGGT -> AGGTT [label="len=6,cov=381.5"]
# 	CTCTC [label="coverage=138"]
# 	CTCTC -> TCTCA [label="len=6,cov=150.5"]
# 	CTCTC -> TCTCG [label="len=6,cov=118.0"]
# 	CTCTC -> TCTCT [label="len=6,cov=304.0"]
# 	CTCTC -> TCTCC [label="len=6,cov=258.5"]
# 	CGGAT [label="coverage=97"]
# 	CGGAT -> GGATA [label="len=6,cov=333.0"]
# 	CGGAT -> GGATC [label="len=6,cov=298.5"]
# 	CGGAT -> GGATG [label="len=6,cov=205.5"]
# 	CGGAT -> GGATT [label="len=6,cov=368.5"]
# 	GTCTA [label="coverage=375"]
# 	GTCTA -> TCTAG [label="len=6,cov=420.0"]
# 	GTCTA -> TCTAA [label="len=6,cov=329.5"]
# 	GTCTA -> TCTAC [label="len=6,cov=196.0"]
# 	GTCTA -> TCTAT [label="len=6,cov=285.5"]
# 	ATTCT [label="coverage=372"]
# 	ATTCT -> TTCTC [label="len=6,cov=390.0"]
# 	ATTCT -> TTCTT [label="len=6,cov=515.5"]
# 	ATTCT -> TTCTA [label="len=6,cov=281.0"]
# 	ATTCT -> TTCTG [label="len=6,cov=331.5"]
# 	TGCTG [label="coverage=740"]
# 	TGCTG -> GCTGA [label="len=6,cov=559.5"]
# 	TGCTG -> GCTGG [label="len=6,cov=700.0"]
# 	TGCTG -> GCTGT [label="len=6,cov=464.0"]
# 	TGCTG -> GCTGC [label="len=6,cov=445.5"]
# }
